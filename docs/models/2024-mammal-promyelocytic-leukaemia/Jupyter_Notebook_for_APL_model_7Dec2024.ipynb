# %% [markdown]
# # Jupyter Notebook for the analysis of the Model for Retinoic Acid resistance in Acute Promyelocytic Leukaemia
#
# José A. Sánchez-Villanueva (1), Lia N’Guyen (2), Mathilde Poplineau (2), Estelle Duprez (2), Élisabeth Remy (1) & Denis Thieffry (3,4)
# 1) Aix Marseille Univ, CNRS, I2M, Marseille, France.
# 2) Integrative molecular biology in hematopoiesis and leukemia, Equipe Labellisée Ligue Contre le Cancer, CRCM, Inserm UMR1068, CNRS UMR7258, Institut Paoli-Calmettes, Aix Marseille Univ, Marseille, France.
# 3) Department of Biology, École Normale Supérieure, Paris, France.
# 4) Institut Curie - INSERM U900 - Mines Paris, PSL Research University, Paris, France.
#
#
# This model analysis workflow was designed to assses the dynamical properties of a logical network model constructed to study Retinoic Acid resistance in Acute Promyelocytic Leukaemia. Execution of the command lines requires installation of the CoLoMoTo environment (https://colomoto.github.io/).
# The model integrates signalling, transcriptional and epigenetic regulatory mechanisms underlying the APL cell responses to RA treatment depending on their genetic background. The explicit inclusion of the histone methyltransferase EZH2 allowed to assess its role in the maintenance of the resistant phenotype, distinguishing between its canonical and non-canonical activities. Ultimately, this model offers a solid basis to assess the roles of novel regulatory mechanisms, as well as to explore novel therapeutical approaches *in silico*.
#
# The analysis workflow includes the following steps:
#
# * loading of the logical model from the GINsim repository and display of the logical regulatory graph(LRG),
# * identification of the attractors (trapspaces and fixpoints),
# * attractors commitment analysis,
# * definition of variants of the model to represent EZH2 perturbations cases,
# * stochastic simulations to evaluate the impact of EZH2 perturbations on the probabilities to reach the differentiated and proliferative phenotypes,
# * a comprehensive perturbation analysis to determine the nodes with stronger contributions to the differentiated or proliferative phenotypes,
# * a parameter sensitivity analysis focused on variations in the activation and deactivation transition rates.

# %%
# Import of the necessary tools and python packages for the whole set of analyses.

import ginsim
import biolqm
import pyboolnet
import maboss

from colomoto_jupyter import tabulate

from pyboolnet.file_exchange import bnet2primes, primes2bnet
from pyboolnet.prime_implicants import find_constants, create_variables, list_input_combinations, create_constants
from pyboolnet.repository import get_primes
from pyboolnet.trap_spaces import compute_trap_spaces, compute_steady_states

from pyboolnet.model_checking import model_checking
from pyboolnet.attractors import compute_attractors
from pyboolnet.commitment_diagrams import compute_commitment_diagram, create_commitment_piechart, commitment_diagram2image
# Out:
# This notebook has been executed using the docker image `colomoto/colomoto-docker:for-next`
# INFO generated new fontManager

# %% [markdown]
# ## Loading of the logical model and displaying of the Logical Regulatory Graph with GINsim

# %%
# Load the model in GINsim format and display the Logical Regulatory Graph.
lrg = ginsim.load("SanchezVillanueva_RA_APL_model_19Nov2024.zginml")  # To load the model file stored locally
# lrg = ginsim.load("http://ginsim.org/sites/default/files/SanchezVillanueva_RA_APL_model_19Aug2024.zginml")  # To load the model file from the GINsim repository
ginsim.show(lrg)
# Out:
# <img class="unconfined" width="100%" src="data:image/svg+xml;base64,...">

# %% [markdown]
# This **logical regulatory graph** encompasses 36 nodes and 131 signed arcs. Internal nodes can be associated with four main functions: cell cycle arrest (red); cell cycle progression (green); granulocytic differentiation (yellow); and epigenetic regulation (orange), integrating components of 3 different layers (signalling, epigenetic and transcriptional) into a common regulatory graph. Oval nodes denote Boolean components, whereas the rectangular one denotes a ternary component (RA). Green arrows and red blunt arcs denote positive and negative regulatory influences, respectively. Three inputs nodes (light blue) denote the presence of translocations (PLM_RARAg or PLZF_RARAg), as well as the RA level considered (No RA: 0, physiological level: 1, and pharmacological level: 2). The graph is complemented with logical rules determining the target level of each node as a function of the levels of its regulators. The model (including logical rules and model annotations) is available in the GINsim repository (http://ginsim.org/node/256), as well as in the BioModels database (SBML qual format).

# %% [markdown]
# ## Identification of the attractors with bioLQM
#
# Logical model attractors can be of two types: single stable states (also named fixpoints), or cyclic attractors, made of circular sequences of two or more states, according to the logical rules.
#
# The *trapspaces* function of bioLQM enables the identification of both types of attractors, while the *fixpoints* function only identifies the stable states. Using both functions we were able to detect that the number of stable states equals the number of minimal trapspaces, presumably ruling out the existence of cyclic attractors. This hypothesis is further verified with the commitment analysis showed below, as all states lead to the stable states in each of the diagrams.

# %%
# Computation of the number of trapspaces and fixpoints of the model.
lqm = ginsim.to_biolqm(lrg)
print("Number of attractors of the model:")
print("trapspaces: "+str(len(biolqm.trapspaces(lqm, "terminal"))))
print("stable states: "+str(len(biolqm.fixpoints(lqm)))+"\n")
# Out:
# Number of attractors of the model:
# trapspaces: 21
# stable states: 21

# %%
# Display of the stable states over selected reporter components
rep_comp = ["RA", "PML_RARAg", "PLZF_RARAg", "PML", "PLZF", "TP53", "CDKN1A", "CDKN1B", "E2F1", "MYC", "RARB", "CEBPAB", "EZH2", "PRC2", "SPI1"]
fps = biolqm.fixpoints(lqm)
fpsproj = biolqm.fixpoints(lqm, autoconvert=False).project_on_components(rep_comp)
display(biolqm.states_to_dataframe(fpsproj).style.set_properties(**{'text-align': 'center'}))
# Out:
# <style type="text/css">
# #T_4b741_row0_col0, #T_4b741_row0_col1, #T_4b741_row0_col2, #T_4b741_row0_col3, #T_4b741_row0_col4, #T_4b741_row0_col5, #T_4b741_row0_col6, #T_4b741_row0_col7, #T_4b741_row0_col8, #T_4b741_row0_col9, #T_4b741_row0_col10, #T_4b741_row0_col11, #T_4b741_row0_col12, #T_4b741_row0_col13, #T_4b741_row0_col14, #T_4b741_row1_col0, #T_4b741_row1_col1, #T_4b741_row1_col2, #T_4b741_row1_col3, #T_4b741_row1_col4, #T_4b741_row1_col5, #T_4b741_row1_col6, #T_4b741_row1_col7, #T_4b741_row1_col8, #T_4b741_row1_col9, #T_4b741_row1_col10, #T_4b741_row1_col11, #T_4b741_row1_col12, #T_4b741_row1_col13, #T_4b741_row1_col14, #T_4b741_row2_col0, #T_4b741_row2_col1, #T_4b741_row2_col2, #T_4b741_row2_col3, #T_4b741_row2_col4, #T_4b741_row2_col5, #T_4b741_row2_col6, #T_4b741_row2_col7, #T_4b741_row2_col8, #T_4b741_row2_col9, #T_4b741_row2_col10, #T_4b741_row2_col11, #T_4b741_row2_col12, #T_4b741_row2_col13, #T_4b741_row2_col14, #T_4b741_row3_col0, #T_4b741_row3_col1, #T_4b741_row3_col2, #T_4b741_row3_col3, #T_4b741_row3_col4, #T_4b741_row3_col5, #T_4b741_row3_col6, #T_4b741_row3_col7, #T_4b741_row3_col8, #T_4b741_row3_col9, #T_4b741_row3_col10, #T_4b741_row3_col11, #T_4b741_row3_col12, #T_4b741_row3_col13, #T_4b741_row3_col14, #T_4b741_row4_col0, #T_4b741_row4_col1, #T_4b741_row4_col2, #T_4b741_row4_col3, #T_4b741_row4_col4, #T_4b741_row4_col5, #T_4b741_row4_col6, #T_4b741_row4_col7, #T_4b741_row4_col8, #T_4b741_row4_col9, #T_4b741_row4_col10, #T_4b741_row4_col11, #T_4b741_row4_col12, #T_4b741_row4_col13, #T_4b741_row4_col14, #T_4b741_row5_col0, #T_4b741_row5_col1, #T_4b741_row5_col2, #T_4b741_row5_col3, #T_4b741_row5_col4, #T_4b741_row5_col5, #T_4b741_row5_col6, #T_4b741_row5_col7, #T_4b741_row5_col8, #T_4b741_row5_col9, #T_4b741_row5_col10, #T_4b741_row5_col11, #T_4b741_row5_col12, #T_4b741_row5_col13, #T_4b741_row5_col14, #T_4b741_row6_col0, #T_4b741_row6_col1, #T_4b741_row6_col2, #T_4b741_row6_col3, #T_4b741_row6_col4, #T_4b741_row6_col5, #T_4b741_row6_col6, #T_4b741_row6_col7, #T_4b741_row6_col8, #T_4b741_row6_col9, #T_4b741_row6_col10, #T_4b741_row6_col11, #T_4b741_row6_col12, #T_4b741_row6_col13, #T_4b741_row6_col14, #T_4b741_row7_col0, #T_4b741_row7_col1, #T_4b741_row7_col2, #T_4b741_row7_col3, #T_4b741_row7_col4, #T_4b741_row7_col5, #T_4b741_row7_col6, #T_4b741_row7_col7, #T_4b741_row7_col8, #T_4b741_row7_col9, #T_4b741_row7_col10, #T_4b741_row7_col11, #T_4b741_row7_col12, #T_4b741_row7_col13, #T_4b741_row7_col14, #T_4b741_row8_col0, #T_4b741_row8_col1, #T_4b741_row8_col2, #T_4b741_row8_col3, #T_4b741_row8_col4, #T_4b741_row8_col5, #T_4b741_row8_col6, #T_4b741_row8_col7, #T_4b741_row8_col8, #T_4b741_row8_col9, #T_4b741_row8_col10, #T_4b741_row8_col11, #T_4b741_row8_col12, #T_4b741_row8_col13, #T_4b741_row8_col14, #T_4b741_row9_col0, #T_4b741_row9_col1, #T_4b741_row9_col2, #T_4b741_row9_col3, #T_4b741_row9_col4, #T_4b741_row9_col5, #T_4b741_row9_col6, #T_4b741_row9_col7, #T_4b741_row9_col8, #T_4b741_row9_col9, #T_4b741_row9_col10, #T_4b741_row9_col11, #T_4b741_row9_col12, #T_4b741_row9_col13, #T_4b741_row9_col14, #T_4b741_row10_col0, #T_4b741_row10_col1, #T_4b741_row10_col2, #T_4b741_row10_col3, #T_4b741_row10_col4, #T_4b741_row10_col5, #T_4b741_row10_col6, #T_4b741_row10_col7, #T_4b741_row10_col8, #T_4b741_row10_col9, #T_4b741_row10_col10, #T_4b741_row10_col11, #T_4b741_row10_col12, #T_4b741_row10_col13, #T_4b741_row10_col14, #T_4b741_row11_col0, #T_4b741_row11_col1, #T_4b741_row11_col2, #T_4b741_row11_col3, #T_4b741_row11_col4, #T_4b741_row11_col5, #T_4b741_row11_col6, #T_4b741_row11_col7, #T_4b741_row11_col8, #T_4b741_row11_col9, #T_4b741_row11_col10, #T_4b741_row11_col11, #T_4b741_row11_col12, #T_4b741_row11_col13, #T_4b741_row11_col14, #T_4b741_row12_col0, #T_4b741_row12_col1, #T_4b741_row12_col2, #T_4b741_row12_col3, #T_4b741_row12_col4, #T_4b741_row12_col5, #T_4b741_row12_col6, #T_4b741_row12_col7, #T_4b741_row12_col8, #T_4b741_row12_col9, #T_4b741_row12_col10, #T_4b741_row12_col11, #T_4b741_row12_col12, #T_4b741_row12_col13, #T_4b741_row ...
#   text-align: center;
# }
# </style>
# <table id="T_4b741">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b741_level0_col0" class="col_heading level0 col0" >RA</th>
#       <th id="T_4b741_level0_col1" class="col_heading level0 col1" >PML_RARAg</th>
#       <th id="T_4b741_level0_col2" class="col_heading level0 col2" >PLZF_RARAg</th>
#       <th id="T_4b741_level0_col3" class="col_heading level0 col3" >PML</th>
#       <th id="T_4b741_level0_col4" class="col_heading level0 col4" >PLZF</th>
#       <th id="T_4b741_level0_col5" class="col_heading level0 col5" >EZH2</th>
#       <th id="T_4b741_level0_col6" class="col_heading level0 col6" >PRC2</th>
#       <th id="T_4b741_level0_col7" class="col_heading level0 col7" >CDKN1A</th>
#       <th id="T_4b741_level0_col8" class="col_heading level0 col8" >CDKN1B</th>
#       <th id="T_4b741_level0_col9" class="col_heading level0 col9" >TP53</th>
#       <th id="T_4b741_level0_col10" class="col_heading level0 col10" >E2F1</th>
#       <th id="T_4b741_level0_col11" class="col_heading level0 col11" >MYC</th>
#       <th id="T_4b741_level0_col12" class="col_heading level0 col12" >SPI1</th>
#       <th id="T_4b741_level0_col13" class="col_heading level0 col13" >CEBPAB</th>
#       <th id="T_4b741_level0_col14" class="col_heading level0 col14" >RARB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b741_level0_row0" class="row_heading l

# %% [markdown]
# The resulting stable states are listed, focusing on the values of a subset of nodes enabling the association of each of the stable states with a specific cellular phenotype.
# The list covers all possible input combinations, including situations corresponding to the simultaneous presence of PML_RARAg and PLZF_RARAg fusions, which has never been reported. This genetic background is thus not further considered in the simulations presented below.
# Using GINsim, we can also visualise any of these stable states directly on the regulatory graph.

# %%
# Display the 8th stable state on the regulatory graph 
ginsim.show(lrg, fps[8])
# Out:
# <img class="unconfined" width="100%" src="data:image/svg+xml;base64,...">

# %% [markdown]
# Nodes in blue are active, while the nodes in white are inactive. This stable state thus corresponds to the differentiated phenotype reached in the presence of medium level of RA (light blue), but in the absence of PML-RARA and PLZF-RARA fusion proteins.

# %% [markdown]
# ## Commitment analysis with pyboolnet
# PyBoolnet can be used to compute the set of states leading towards each of the attractors.
# It relies in the model checking tool NuSMV.
# A commitment diagram is generated for each of the input combinations.
# The resulting diagrams are saved in json format and as images in PDF format.

# %%
# %%time

# Export of the biolqm model to pyboolnet for commitment analysis
bnet = biolqm.save(lqm, "bnet.bnet", "bnet")
pbn = bnet2primes(bnet)
# Out:
# CPU times: user 37.9 ms, sys: 9.94 ms, total: 47.8 ms
# Wall time: 1min 1s

# %%
# %%time 

# Definition and storing of the relevant input combinations into a dictionary

pbn_input_configurations = {
    'WT_RA0_pbn': {'PLZF_RARAg': 0, 'PML_RARAg': 0, 'RA_b1': 0, 'RA_b2': 0},
    'WT_RA1_pbn': {'PLZF_RARAg': 0, 'PML_RARAg': 0, 'RA_b1': 1, 'RA_b2': 0},
    'WT_RA2_pbn': {'PLZF_RARAg': 0, 'PML_RARAg': 0, 'RA_b1': 1, 'RA_b2': 1},
    'PM_RA0_pbn': {'PLZF_RARAg': 0, 'PML_RARAg': 1, 'RA_b1': 0, 'RA_b2': 0},
    'PM_RA1_pbn': {'PLZF_RARAg': 0, 'PML_RARAg': 1, 'RA_b1': 1, 'RA_b2': 0},
    'PM_RA2_pbn': {'PLZF_RARAg': 0, 'PML_RARAg': 1, 'RA_b1': 1, 'RA_b2': 1},
    'PZ_RA0_pbn': {'PLZF_RARAg': 1, 'PML_RARAg': 0, 'RA_b1': 0, 'RA_b2': 0},
    'PZ_RA1_pbn': {'PLZF_RARAg': 1, 'PML_RARAg': 0, 'RA_b1': 1, 'RA_b2': 0},
    'PZ_RA2_pbn': {'PLZF_RARAg': 1, 'PML_RARAg': 0, 'RA_b1': 1, 'RA_b2': 1},
}

# Create the primes_dict using a loop
primes_dict = {name: create_constants(pbn, config, copy=True) for name, config in pbn_input_configurations.items()}
# Out:
# CPU times: user 4.09 ms, sys: 988 μs, total: 5.08 ms
# Wall time: 5 ms

# %%
# %%time  

# This cell computations take about 10'

# Commitment analysis for each of the input combinations. This step takes some time (around 20 mins on an Apple M1 Pro, 32 GB).
# A diagram in json format will be generated, and a PDF file with the image of the commitment diagram.
attractors_dict={}
diagrams_dict = {}
for k, v in primes_dict.items():
    attractors = compute_attractors(primes=v, update="asynchronous")
    attractors_dict['attractors'+'_'+str(k)]=attractors
    diagram = compute_commitment_diagram(attractors=attractors, fname_json=str(k)+'_commitment_diagram.json', edge_data=True)
    diagrams_dict['diagram'+'_'+str(k)]=diagram
    if len(attractors_dict['attractors'+'_'+str(k)]['attractors'])==1:
        continue
    commitment_diagram2image(diagram=diagram, fname_image=str(k)+'_commitment_diagram.pdf', style_inputs=True, style_edges=True, style_ranks=True, first_index= 1)
# Out:
# INFO attractors.completeness(..)
# INFO created /tmp/pyboolnet_n3n6jf4z
# INFO yes
# INFO  working on minimal trapspace 1/2: 1111110000011011011000000111000011001
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 1111110000011011011000000111000011001
# INFO end: 1111110000011011011000000111000011001
# INFO created /tmp/pyboolnet_iefatc4k
# INFO is attractor state
# INFO  working on minimal trapspace 2/2: 0000001100011101100100100101000110010
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 0000001100011101100100100101000110010
# INFO end: 0000001100011101100100100101000110010
# INFO created /tmp/pyboolnet_3gjvd5u_
# INFO is attractor state
# INFO Commitment.compute_diagram(..)
# INFO excluding the non-critical out-dag nodes []
# INFO working on 1 connected component(s)
# INFO _compute_diagram_component(..)
# INFO inputs: 0 ()
# INFO combinations:  1
# INFO input combination 0, worst case #nodes: 3
# INFO created /tmp/pyboolnet_4wl6t2km
# INFO created /tmp/pyboolnet_6c8vddv_
# INFO created /tmp/pyboolnet_wfuv1rat
# INFO worst case #nodes: 3
# INFO actual nodes: 3 = 100.0
# INFO worst case #edges: 2
# INFO created /tmp/pyboolnet_sdy5k_dl
# INFO created /tmp/pyboolnet_q03c58e2
# INFO created /tmp/pyboolnet_gm9mb3eh
# INFO created /tmp/pyboolnet_lkytk0g4
# INFO actual edges: 2 = 100.00%
# INFO total executions of NuSMV: 7
# INFO total executions of NuSMV: 7
# INFO created WT_RA0_pbn_commitment_diagram.json
# INFO created WT_RA0_pbn_commitment_diagram.pdf
# INFO attractors.completeness(..)
# INFO yes
# INFO  working on minimal trapspace 1/1: 0000001111111000000000100101110110110
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 0000001111111000000000100101110110110
# INFO end: 0000001111111000000000100101110110110
# INFO created /tmp/pyboolnet_6hsthuts
# INFO is attractor state
# INFO Commitment.compute_diagram(..)
# INFO  single attractor, trivial case.
# INFO total executions of NuSMV: 0
# INFO created WT_RA1_pbn_commitment_diagram.json
# INFO attractors.completeness(..)
# INFO yes
# INFO  working on minimal trapspace 1/1: 0000001111111000000000100101111110110
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 0000001111111000000000100101111110110
# INFO end: 0000001111111000000000100101111110110
# INFO created /tmp/pyboolnet_rhdoj6z2
# INFO is attractor state
# INFO Commitment.compute_diagram(..)
# INFO  single attractor, trivial case.
# INFO total executions of NuSMV: 0
# INFO created WT_RA2_pbn_commitment_diagram.json
# INFO attractors.completeness(..)
# INFO created /tmp/pyboolnet_ubuod8yy
# INFO yes
# INFO  working on minimal trapspace 1/2: 1111110000011011011000011111000011001
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 1111110000011011011000011111000011001
# INFO end: 1111110000011011011000011111000011001
# INFO created /tmp/pyboolnet_bb7c5qvq
# INFO is attractor state
# INFO  working on minimal trapspace 2/2: 0000001100011101100100101101000110010
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 0000001100011101100100101101000110010
# INFO end: 0000001100011101100100101101000110010
# INFO created /tmp/pyboolnet_mmlunrdr
# INFO is attractor state
# INFO Commitment.compute_diagram(..)
# INFO excluding the non-critical out-dag nodes []
# INFO working on 1 connected component(s)
# INFO _compute_diagram_component(..)
# INFO inputs: 0 ()
# INFO combinations:  1
# INFO input combination 0, worst case #nodes: 3
# INFO created /tmp/pyboolnet_9o_rnwax
# INFO created /tmp/pyboolnet_c917t4xu
# INFO created /tmp/pyboolnet_7hlou1ie
# INFO worst case #nodes: 3
# INFO actual nodes: 3 = 100.0
# INFO worst case #edges: 2
# INFO created /tmp/pyboolnet_riw9kw2j
# INFO created /tmp/pyboolnet_2rr2f2s_
# INFO created /tmp/pyboolnet_gs2vhe1q
# INFO created /tmp/pyboolnet_mm9x4nui
# INFO actual edges: 2 = 100.00%
# INFO total executions of NuSMV: 7
# INFO total executions of NuSMV: 7
# INFO created PM_RA0_pbn_commitment_diagram.json
# INFO created PM_RA0_pbn_commitment_diagram.pdf
# INFO attractors.completeness(..)
# INFO created /tmp/pyboolnet_z4n48u5t
# INFO yes
# INFO  working on minimal trapspace 1/2: 0000001111111000000000101101110110110
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 0000001111111000000000101101110110110
# INFO end: 0000001111111000000000101101110110110
# INFO created /tmp/pyboolnet_o1syi6bf
# INFO is attractor state
# INFO  working on minimal trapspace 2/2: 1111110000011011011000011111010011001
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 1111110000011011011000011111010011001
# INFO end: 1111110000011011011000011111010011001
# INFO created /tmp/pyboolnet_kx5xbmuw
# INFO is attractor state
# INFO Commitment.compute_diagram(..)
# INFO excluding the non-critical out-dag nodes []
# INFO working on 1 connected component(s)
# INFO _compute_diagram_component(..)
# INFO inputs: 0 ()
# INFO combinations:  1
# INFO input combination 0, worst case #nodes: 3
# INFO created /tmp/pyboolnet_sq01vci7
# INFO created /tmp/pyboolnet_fci6ff7i
# INFO created /tmp/pyboolnet_s0ugaypm
# INFO worst case #nodes: 3
# INFO actual nodes: 3 = 100.0
# INFO worst case #edges: 2
# INFO created /tmp/pyboolnet_bzplc_kj
# INFO created /tmp/pyboolnet_7ow6a7hz
# INFO created /tmp/pyboolnet_5in7fceg
# INFO created /tmp/pyboolnet_75x7cp8h
# INFO actual edges: 2 = 100.00%
# INFO total executions of NuSMV: 7
# INFO total executions of NuSMV: 7
# INFO created PM_RA1_pbn_commitment_diagram.json
# INFO created PM_RA1_pbn_commitment_diagram.pdf
# INFO attractors.completeness(..)
# INFO yes
# INFO  working on minimal trapspace 1/1: 0000001111111000000000101101111110110
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 0000001111111000000000101101111110110
# INFO end: 0000001111111000000000101101111110110
# INFO created /tmp/pyboolnet_83ph3knw
# INFO is attractor state
# INFO Commitment.compute_diagram(..)
# INFO  single attractor, trivial case.
# INFO total executions of NuSMV: 0
# INFO created PM_RA2_pbn_commitment_diagram.json
# INFO attractors.completeness(..)
# INFO created /tmp/pyboolnet_p1nnn9_2
# INFO yes
# INFO  working on minimal trapspace 1/2: 1111110000011011011011000111000001001
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 1111110000011011011011000111000001001
# INFO end: 1111110000011011011011000111000001001
# INFO created /tmp/pyboolnet_7se3oxkt
# INFO is attractor state
# INFO  working on minimal trapspace 2/2: 0000001100011101100101100101000110010
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 0000001100011101100101100101000110010
# INFO end: 0000001100011101100101100101000110010
# INFO created /tmp/pyboolnet_pduwmg0u
# INFO is attractor state
# INFO Commitment.compute_diagram(..)
# INFO excluding the non-critical out-dag nodes []
# INFO working on 1 connected component(s)
# INFO _compute_diagram_component(..)
# INFO inputs: 0 ()
# INFO combinations:  1
# INFO input combination 0, worst case #nodes: 3
# INFO created /tmp/pyboolnet_afiu0741
# INFO created /tmp/pyboolnet_6tlh5o3l
# INFO created /tmp/pyboolnet__rjlmr49
# INFO worst case #nodes: 3
# INFO actual nodes: 3 = 100.0
# INFO worst case #edges: 2
# INFO created /tmp/pyboolnet_und61xfi
# INFO created /tmp/pyboolnet_372_am90
# INFO created /tmp/pyboolnet_luh9_3uh
# INFO created /tmp/pyboolnet_2ffq4h4s
# INFO actual edges: 2 = 100.00%
# INFO total executions of NuSMV: 7
# INFO total executions of NuSMV: 7
# INFO created PZ_RA0_pbn_commitment_diagram.json
# INFO created PZ_RA0_pbn_commitment_diagram.pdf
# INFO attractors.completeness(..)
# INFO created /tmp/pyboolnet_0smu98ig
# INFO yes
# INFO  working on minimal trapspace 1/2: 1111110000011011011011000111010001001
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 1111110000011011011011000111010001001
# INFO end: 1111110000011011011011000111010001001
# INFO created /tmp/pyboolnet_bundnr9b
# INFO is attractor state
# INFO  working on minimal trapspace 2/2: 0000001111111000000001100101110110110
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 0000001111111000000001100101110110110
# INFO end: 0000001111111000000001100101110110110
# INFO created /tmp/pyboolnet_r9igrane
# INFO is attractor state
# INFO Commitment.compute_diagram(..)
# INFO excluding the non-critical out-dag nodes []
# INFO working on 1 connected component(s)
# INFO _compute_diagram_component(..)
# INFO inputs: 0 ()
# INFO combinations:  1
# INFO input combination 0, worst case #nodes: 3
# INFO created /tmp/pyboolnet_ahx2q_ge
# INFO created /tmp/pyboolnet_yq6lkctq
# INFO created /tmp/pyboolnet_049_va_q
# INFO worst case #nodes: 3
# INFO actual nodes: 3 = 100.0
# INFO worst case #edges: 2
# INFO created /tmp/pyboolnet_zlol1zdx
# INFO created /tmp/pyboolnet_8jpftzeu
# INFO created /tmp/pyboolnet_coutlini
# INFO created /tmp/pyboolnet_adips65w
# INFO actual edges: 2 = 100.00%
# INFO total executions of NuSMV: 7
# INFO total executions of NuSMV: 7
# INFO created PZ_RA1_pbn_commitment_diagram.json
# INFO created PZ_RA1_pbn_commitment_diagram.pdf
# INFO attractors.completeness(..)
# INFO created /tmp/pyboolnet_9in9bu1g
# INFO yes
# INFO  working on minimal trapspace 1/2: 1111110000011011011011000111011001001
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 1111110000011011011011000111011001001
# INFO end: 1111110000011011011011000111011001001
# INFO created /tmp/pyboolnet__adn4qgi
# INFO is attractor state
# INFO  working on minimal trapspace 2/2: 0000001111111000000001100101111110110
# INFO attractors.univocality(..)
# INFO  yes
# INFO attractors.faithfulness(..)
# INFO yes
# INFO attractors.find_attractor_state_by_randomwalk_and_ctl(..)
# INFO find_attractor_state_by_randomwalk_and_ctl(..)
# INFO len(primes)=37, update='asynchronous', length=370, attempts=10
# INFO trial 0
# INFO start: 0000001111111000000001100101111110110
# INFO end: 0000001111111000000001100101111110110
# INFO created /tmp/pyboolnet_oksz873r
# INFO is attractor state
# INFO Commitment.compute_diagram(..)
# INFO excluding the non-critical out-dag nodes []
# INFO working on 1 connected component(s)
# INFO _compute_diagram_component(..)
# INFO inputs: 0 ()
# INFO combinations:  1
# INFO input combination 0, worst case #nodes: 3
# INFO created /tmp/pyboolnet_spjbep0q
# INFO created /tmp/pyboolnet_lbtzljqz
# INFO created /tmp/pyboolnet_d9pt0ngw
# INFO worst case #nodes: 3
# INFO actual nodes: 3 = 100.0
# INFO worst case #edges: 2
# INFO created /tmp/pyboolnet_242xbcsx
# INFO created /tmp/pyboolnet_kt4vw5fe
# INFO created /tmp/pyboolnet_ukkwq1o4
# INFO created /tmp/pyboolnet_jzk6yowp
# INFO actual edges: 2 = 100.00%
# INFO total executions of NuSMV: 7
# INFO total executions of NuSMV: 7
# INFO created PZ_RA2_pbn_commitment_diagram.json
# INFO created PZ_RA2_pbn_commitment_diagram.pdf
# CPU times: user 5.79 s, sys: 1.16 s, total: 6.95 s
# Wall time: 13min 15s

# %% [markdown]
# # Analysis of EZH2 perturbations
# In order to analyse the role of EZH2 in cell fate decision, we consider two variants of the APL model:
# i) a complete knockdown of EZH2, or the use of a specific degrader such as MS1943 (model variant EZH2 KO);
# ii) an edgetic perturbation amounting to block the regulatory influence of EZH2 onto PCR2, mimicking the experimental inhibition of EZH2 methyltransferase activity with a chemical agent such as GSK126 (model variant EZH2:PRC2%0)

# %% [markdown]
# ## Definition of EZH2 Model variants with bioLQM

# %%
# Definition of mutants with biolqm, and storing into a dictionary

lqm = ginsim.to_biolqm(lrg)
lqm_EZH2_PRC20 = biolqm.perturbation(lqm, "EZH2:PRC2%0")
lqm_EZH2KO = biolqm.perturbation(lqm, "EZH2%0")

lqm_models = {'No perturbation':lqm, 'EZH2:PRC2%0':lqm_EZH2_PRC20, 'EZH2 KO':lqm_EZH2KO}

# %% [markdown]
# ## Computation of the attractors for the two EZH2 model variants with bioLQM

# %%
# Computation of the number of trapspaces and fixpoints for the two EZH2 perturbations with bioLQM.

print("Number of attractors for the edgetic perturbation affecting the effect of EZH2 onto PRC2 (EZH2:PRC2%0):")
print("trapspaces: "+str(len(biolqm.trapspaces(lqm_EZH2_PRC20, "terminal"))))
print("stable states: "+str(len(biolqm.fixpoints(lqm_EZH2_PRC20)))+"\n")

print("Number of attractors for EZH2 knockout (EZH2 KO):")
print("trapspaces: "+str(len(biolqm.trapspaces(lqm_EZH2KO, "terminal"))))
print("stable states: "+str(len(biolqm.fixpoints(lqm_EZH2KO)))+"\n")
# Out:
# Number of attractors for the edgetic perturbation affecting the effect of EZH2 onto PRC2 (EZH2:PRC2%0):
# trapspaces: 21
# stable states: 21
#
# Number of attractors for EZH2 knockout (EZH2 KO):
# trapspaces: 12
# stable states: 12

# %%
# Display of the fixpoints for the EZH2_PRC20 condition over selected reporter components.
rep_comp = ["RA", "PML_RARAg", "PLZF_RARAg", "PML", "PLZF", "TP53", "CDKN1A", "CDKN1B", "E2F1", "MYC", "RARB", "CEBPAB", "EZH2", "PRC2", "SPI1"]
fps_EZH2_PRC20 = biolqm.fixpoints(lqm_EZH2_PRC20, autoconvert=False).project_on_components(rep_comp)
display(biolqm.states_to_dataframe(fps_EZH2_PRC20).style.set_properties(**{'text-align': 'center'}))
# Out:
# <style type="text/css">
# #T_e8b58_row0_col0, #T_e8b58_row0_col1, #T_e8b58_row0_col2, #T_e8b58_row0_col3, #T_e8b58_row0_col4, #T_e8b58_row0_col5, #T_e8b58_row0_col6, #T_e8b58_row0_col7, #T_e8b58_row0_col8, #T_e8b58_row0_col9, #T_e8b58_row0_col10, #T_e8b58_row0_col11, #T_e8b58_row0_col12, #T_e8b58_row0_col13, #T_e8b58_row0_col14, #T_e8b58_row1_col0, #T_e8b58_row1_col1, #T_e8b58_row1_col2, #T_e8b58_row1_col3, #T_e8b58_row1_col4, #T_e8b58_row1_col5, #T_e8b58_row1_col6, #T_e8b58_row1_col7, #T_e8b58_row1_col8, #T_e8b58_row1_col9, #T_e8b58_row1_col10, #T_e8b58_row1_col11, #T_e8b58_row1_col12, #T_e8b58_row1_col13, #T_e8b58_row1_col14, #T_e8b58_row2_col0, #T_e8b58_row2_col1, #T_e8b58_row2_col2, #T_e8b58_row2_col3, #T_e8b58_row2_col4, #T_e8b58_row2_col5, #T_e8b58_row2_col6, #T_e8b58_row2_col7, #T_e8b58_row2_col8, #T_e8b58_row2_col9, #T_e8b58_row2_col10, #T_e8b58_row2_col11, #T_e8b58_row2_col12, #T_e8b58_row2_col13, #T_e8b58_row2_col14, #T_e8b58_row3_col0, #T_e8b58_row3_col1, #T_e8b58_row3_col2, #T_e8b58_row3_col3, #T_e8b58_row3_col4, #T_e8b58_row3_col5, #T_e8b58_row3_col6, #T_e8b58_row3_col7, #T_e8b58_row3_col8, #T_e8b58_row3_col9, #T_e8b58_row3_col10, #T_e8b58_row3_col11, #T_e8b58_row3_col12, #T_e8b58_row3_col13, #T_e8b58_row3_col14, #T_e8b58_row4_col0, #T_e8b58_row4_col1, #T_e8b58_row4_col2, #T_e8b58_row4_col3, #T_e8b58_row4_col4, #T_e8b58_row4_col5, #T_e8b58_row4_col6, #T_e8b58_row4_col7, #T_e8b58_row4_col8, #T_e8b58_row4_col9, #T_e8b58_row4_col10, #T_e8b58_row4_col11, #T_e8b58_row4_col12, #T_e8b58_row4_col13, #T_e8b58_row4_col14, #T_e8b58_row5_col0, #T_e8b58_row5_col1, #T_e8b58_row5_col2, #T_e8b58_row5_col3, #T_e8b58_row5_col4, #T_e8b58_row5_col5, #T_e8b58_row5_col6, #T_e8b58_row5_col7, #T_e8b58_row5_col8, #T_e8b58_row5_col9, #T_e8b58_row5_col10, #T_e8b58_row5_col11, #T_e8b58_row5_col12, #T_e8b58_row5_col13, #T_e8b58_row5_col14, #T_e8b58_row6_col0, #T_e8b58_row6_col1, #T_e8b58_row6_col2, #T_e8b58_row6_col3, #T_e8b58_row6_col4, #T_e8b58_row6_col5, #T_e8b58_row6_col6, #T_e8b58_row6_col7, #T_e8b58_row6_col8, #T_e8b58_row6_col9, #T_e8b58_row6_col10, #T_e8b58_row6_col11, #T_e8b58_row6_col12, #T_e8b58_row6_col13, #T_e8b58_row6_col14, #T_e8b58_row7_col0, #T_e8b58_row7_col1, #T_e8b58_row7_col2, #T_e8b58_row7_col3, #T_e8b58_row7_col4, #T_e8b58_row7_col5, #T_e8b58_row7_col6, #T_e8b58_row7_col7, #T_e8b58_row7_col8, #T_e8b58_row7_col9, #T_e8b58_row7_col10, #T_e8b58_row7_col11, #T_e8b58_row7_col12, #T_e8b58_row7_col13, #T_e8b58_row7_col14, #T_e8b58_row8_col0, #T_e8b58_row8_col1, #T_e8b58_row8_col2, #T_e8b58_row8_col3, #T_e8b58_row8_col4, #T_e8b58_row8_col5, #T_e8b58_row8_col6, #T_e8b58_row8_col7, #T_e8b58_row8_col8, #T_e8b58_row8_col9, #T_e8b58_row8_col10, #T_e8b58_row8_col11, #T_e8b58_row8_col12, #T_e8b58_row8_col13, #T_e8b58_row8_col14, #T_e8b58_row9_col0, #T_e8b58_row9_col1, #T_e8b58_row9_col2, #T_e8b58_row9_col3, #T_e8b58_row9_col4, #T_e8b58_row9_col5, #T_e8b58_row9_col6, #T_e8b58_row9_col7, #T_e8b58_row9_col8, #T_e8b58_row9_col9, #T_e8b58_row9_col10, #T_e8b58_row9_col11, #T_e8b58_row9_col12, #T_e8b58_row9_col13, #T_e8b58_row9_col14, #T_e8b58_row10_col0, #T_e8b58_row10_col1, #T_e8b58_row10_col2, #T_e8b58_row10_col3, #T_e8b58_row10_col4, #T_e8b58_row10_col5, #T_e8b58_row10_col6, #T_e8b58_row10_col7, #T_e8b58_row10_col8, #T_e8b58_row10_col9, #T_e8b58_row10_col10, #T_e8b58_row10_col11, #T_e8b58_row10_col12, #T_e8b58_row10_col13, #T_e8b58_row10_col14, #T_e8b58_row11_col0, #T_e8b58_row11_col1, #T_e8b58_row11_col2, #T_e8b58_row11_col3, #T_e8b58_row11_col4, #T_e8b58_row11_col5, #T_e8b58_row11_col6, #T_e8b58_row11_col7, #T_e8b58_row11_col8, #T_e8b58_row11_col9, #T_e8b58_row11_col10, #T_e8b58_row11_col11, #T_e8b58_row11_col12, #T_e8b58_row11_col13, #T_e8b58_row11_col14, #T_e8b58_row12_col0, #T_e8b58_row12_col1, #T_e8b58_row12_col2, #T_e8b58_row12_col3, #T_e8b58_row12_col4, #T_e8b58_row12_col5, #T_e8b58_row12_col6, #T_e8b58_row12_col7, #T_e8b58_row12_col8, #T_e8b58_row12_col9, #T_e8b58_row12_col10, #T_e8b58_row12_col11, #T_e8b58_row12_col12, #T_e8b58_row12_col13, #T_e8b58_row ...
#   text-align: center;
# }
# </style>
# <table id="T_e8b58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8b58_level0_col0" class="col_heading level0 col0" >RA</th>
#       <th id="T_e8b58_level0_col1" class="col_heading level0 col1" >PML_RARAg</th>
#       <th id="T_e8b58_level0_col2" class="col_heading level0 col2" >PLZF_RARAg</th>
#       <th id="T_e8b58_level0_col3" class="col_heading level0 col3" >PML</th>
#       <th id="T_e8b58_level0_col4" class="col_heading level0 col4" >PLZF</th>
#       <th id="T_e8b58_level0_col5" class="col_heading level0 col5" >EZH2</th>
#       <th id="T_e8b58_level0_col6" class="col_heading level0 col6" >PRC2</th>
#       <th id="T_e8b58_level0_col7" class="col_heading level0 col7" >CDKN1A</th>
#       <th id="T_e8b58_level0_col8" class="col_heading level0 col8" >CDKN1B</th>
#       <th id="T_e8b58_level0_col9" class="col_heading level0 col9" >TP53</th>
#       <th id="T_e8b58_level0_col10" class="col_heading level0 col10" >E2F1</th>
#       <th id="T_e8b58_level0_col11" class="col_heading level0 col11" >MYC</th>
#       <th id="T_e8b58_level0_col12" class="col_heading level0 col12" >SPI1</th>
#       <th id="T_e8b58_level0_col13" class="col_heading level0 col13" >CEBPAB</th>
#       <th id="T_e8b58_level0_col14" class="col_heading level0 col14" >RARB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8b58_level0_row0" class="row_heading l

# %% [markdown]
# After comparing this list with the list of stable states obtained above, we conclude that there is no significant impact of this epigenetic perturbation.

# %%
# Display of the fixpoints for the EZH2KO condition over selected reporter components.
fps_EZH2KO = biolqm.fixpoints(lqm_EZH2KO, autoconvert=False).project_on_components(rep_comp)
display(biolqm.states_to_dataframe(fps_EZH2KO).style.set_properties(**{'text-align': 'center'}))
# Out:
# <style type="text/css">
# #T_7e0dd_row0_col0, #T_7e0dd_row0_col1, #T_7e0dd_row0_col2, #T_7e0dd_row0_col3, #T_7e0dd_row0_col4, #T_7e0dd_row0_col5, #T_7e0dd_row0_col6, #T_7e0dd_row0_col7, #T_7e0dd_row0_col8, #T_7e0dd_row0_col9, #T_7e0dd_row0_col10, #T_7e0dd_row0_col11, #T_7e0dd_row0_col12, #T_7e0dd_row0_col13, #T_7e0dd_row0_col14, #T_7e0dd_row1_col0, #T_7e0dd_row1_col1, #T_7e0dd_row1_col2, #T_7e0dd_row1_col3, #T_7e0dd_row1_col4, #T_7e0dd_row1_col5, #T_7e0dd_row1_col6, #T_7e0dd_row1_col7, #T_7e0dd_row1_col8, #T_7e0dd_row1_col9, #T_7e0dd_row1_col10, #T_7e0dd_row1_col11, #T_7e0dd_row1_col12, #T_7e0dd_row1_col13, #T_7e0dd_row1_col14, #T_7e0dd_row2_col0, #T_7e0dd_row2_col1, #T_7e0dd_row2_col2, #T_7e0dd_row2_col3, #T_7e0dd_row2_col4, #T_7e0dd_row2_col5, #T_7e0dd_row2_col6, #T_7e0dd_row2_col7, #T_7e0dd_row2_col8, #T_7e0dd_row2_col9, #T_7e0dd_row2_col10, #T_7e0dd_row2_col11, #T_7e0dd_row2_col12, #T_7e0dd_row2_col13, #T_7e0dd_row2_col14, #T_7e0dd_row3_col0, #T_7e0dd_row3_col1, #T_7e0dd_row3_col2, #T_7e0dd_row3_col3, #T_7e0dd_row3_col4, #T_7e0dd_row3_col5, #T_7e0dd_row3_col6, #T_7e0dd_row3_col7, #T_7e0dd_row3_col8, #T_7e0dd_row3_col9, #T_7e0dd_row3_col10, #T_7e0dd_row3_col11, #T_7e0dd_row3_col12, #T_7e0dd_row3_col13, #T_7e0dd_row3_col14, #T_7e0dd_row4_col0, #T_7e0dd_row4_col1, #T_7e0dd_row4_col2, #T_7e0dd_row4_col3, #T_7e0dd_row4_col4, #T_7e0dd_row4_col5, #T_7e0dd_row4_col6, #T_7e0dd_row4_col7, #T_7e0dd_row4_col8, #T_7e0dd_row4_col9, #T_7e0dd_row4_col10, #T_7e0dd_row4_col11, #T_7e0dd_row4_col12, #T_7e0dd_row4_col13, #T_7e0dd_row4_col14, #T_7e0dd_row5_col0, #T_7e0dd_row5_col1, #T_7e0dd_row5_col2, #T_7e0dd_row5_col3, #T_7e0dd_row5_col4, #T_7e0dd_row5_col5, #T_7e0dd_row5_col6, #T_7e0dd_row5_col7, #T_7e0dd_row5_col8, #T_7e0dd_row5_col9, #T_7e0dd_row5_col10, #T_7e0dd_row5_col11, #T_7e0dd_row5_col12, #T_7e0dd_row5_col13, #T_7e0dd_row5_col14, #T_7e0dd_row6_col0, #T_7e0dd_row6_col1, #T_7e0dd_row6_col2, #T_7e0dd_row6_col3, #T_7e0dd_row6_col4, #T_7e0dd_row6_col5, #T_7e0dd_row6_col6, #T_7e0dd_row6_col7, #T_7e0dd_row6_col8, #T_7e0dd_row6_col9, #T_7e0dd_row6_col10, #T_7e0dd_row6_col11, #T_7e0dd_row6_col12, #T_7e0dd_row6_col13, #T_7e0dd_row6_col14, #T_7e0dd_row7_col0, #T_7e0dd_row7_col1, #T_7e0dd_row7_col2, #T_7e0dd_row7_col3, #T_7e0dd_row7_col4, #T_7e0dd_row7_col5, #T_7e0dd_row7_col6, #T_7e0dd_row7_col7, #T_7e0dd_row7_col8, #T_7e0dd_row7_col9, #T_7e0dd_row7_col10, #T_7e0dd_row7_col11, #T_7e0dd_row7_col12, #T_7e0dd_row7_col13, #T_7e0dd_row7_col14, #T_7e0dd_row8_col0, #T_7e0dd_row8_col1, #T_7e0dd_row8_col2, #T_7e0dd_row8_col3, #T_7e0dd_row8_col4, #T_7e0dd_row8_col5, #T_7e0dd_row8_col6, #T_7e0dd_row8_col7, #T_7e0dd_row8_col8, #T_7e0dd_row8_col9, #T_7e0dd_row8_col10, #T_7e0dd_row8_col11, #T_7e0dd_row8_col12, #T_7e0dd_row8_col13, #T_7e0dd_row8_col14, #T_7e0dd_row9_col0, #T_7e0dd_row9_col1, #T_7e0dd_row9_col2, #T_7e0dd_row9_col3, #T_7e0dd_row9_col4, #T_7e0dd_row9_col5, #T_7e0dd_row9_col6, #T_7e0dd_row9_col7, #T_7e0dd_row9_col8, #T_7e0dd_row9_col9, #T_7e0dd_row9_col10, #T_7e0dd_row9_col11, #T_7e0dd_row9_col12, #T_7e0dd_row9_col13, #T_7e0dd_row9_col14, #T_7e0dd_row10_col0, #T_7e0dd_row10_col1, #T_7e0dd_row10_col2, #T_7e0dd_row10_col3, #T_7e0dd_row10_col4, #T_7e0dd_row10_col5, #T_7e0dd_row10_col6, #T_7e0dd_row10_col7, #T_7e0dd_row10_col8, #T_7e0dd_row10_col9, #T_7e0dd_row10_col10, #T_7e0dd_row10_col11, #T_7e0dd_row10_col12, #T_7e0dd_row10_col13, #T_7e0dd_row10_col14, #T_7e0dd_row11_col0, #T_7e0dd_row11_col1, #T_7e0dd_row11_col2, #T_7e0dd_row11_col3, #T_7e0dd_row11_col4, #T_7e0dd_row11_col5, #T_7e0dd_row11_col6, #T_7e0dd_row11_col7, #T_7e0dd_row11_col8, #T_7e0dd_row11_col9, #T_7e0dd_row11_col10, #T_7e0dd_row11_col11, #T_7e0dd_row11_col12, #T_7e0dd_row11_col13, #T_7e0dd_row11_col14 {
#   text-align: center;
# }
# </style>
# <table id="T_7e0dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e0dd_level0_col0" class="col_heading level0 col0" >RA</th>
#       <th id="T_7e0dd_level0_col1" class="col_heading level0 col1" >PML_RARAg</th>
#       <th id="T_7e0dd_level0_col2" class="col_heading level0 col2" >PLZF_RARAg</th>
#       <th id="T_7e0dd_level0_col3" class="col_heading level0 col3" >PML</th>
#       <th id="T_7e0dd_level0_col4" class="col_heading level0 col4" >PLZF</th>
#       <th id="T_7e0dd_level0_col5" class="col_heading level0 col5" >EZH2</th>
#       <th id="T_7e0dd_level0_col6" class="col_heading level0 col6" >PRC2</th>
#       <th id="T_7e0dd_level0_col7" class="col_heading level0 col7" >CDKN1A</th>
#       <th id="T_7e0dd_level0_col8" class="col_heading level0 col8" >CDKN1B</th>
#       <th id="T_7e0dd_level0_col9" class="col_heading level0 col9" >TP53</th>
#       <th id="T_7e0dd_level0_col10" class="col_heading level0 col10" >E2F1</th>
#       <th id="T_7e0dd_level0_col11" class="col_heading level0 col11" >MYC</th>
#       <th id="T_7e0dd_level0_col12" class="col_heading level0 col12" >SPI1</th>
#       <th id="T_7e0dd_level0_col13" class="col_heading level0 col13" >CEBPAB</th>
#       <th id="T_7e0dd_level0_col14" class="col_heading level0 col14" >RARB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e0dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e0dd_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7e0dd_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_7e0dd_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_7e0dd_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_7e0dd_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_7e0dd_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_7e0dd_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_7e0dd_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_7e0dd_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_7e0dd_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_7e0dd_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_7e0dd_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_7e0dd_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_7e0dd_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_7e0dd_row0_col14" class="data row0 col14" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7e0dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e0dd_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_7e0dd_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_7e0dd_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_7e0dd_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_7e0dd_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_7e0dd_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_7e0dd_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_7e0dd_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_7e0dd_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_7e0dd_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_7e0dd_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_7e0dd_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_7e0dd_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_7e0dd_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_7e0dd_row1_col14" class="data row1 col14" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7e0dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e0dd_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_7e0dd_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_7e0dd_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_7e0dd_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_7e0dd_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_7e0dd_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_7e0dd_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_7e0dd_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_7e0dd_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_7e0dd_row2_col9" class="data row2 col9" >1</td>
#       <td id="T_7e0dd_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_7e0dd_row2

# %% [markdown]
# The loss-of-function of EZH2 leads to the loss of the 9 stable states corresponding to the proliferative phenotype.

# %% [markdown]
# ## Stochastic simulations to evaluate the impact of EZH2 perturbations in the PLZF::RARA background with MaBoSS
# In order to further characterise the respective impacts of the two EZH2 peturbations, we performed stochastic simulations of the APL model for three conditions:
# * No perturbation
# * EZH2:PRC2%0
# * EZH2 KO
#
# The simulations were performed with the software MaBoSS, using a state representing the Granulocyte-monocyte progenitor stage as initial state, under physiological (RA = 1) and pharmacological (RA = 2) levels of Retinoic Acid.
# The nodes PLZF_RARAg, RARA, PML, PLZF, USP37, CoAct_COMP, EZH2, PRC2, CoRep_COMP, CDKN2D, RB1, SKP2, MDM2, CAK, CCNA2, CCND1, CCNE2, CDK4_6, CDK2, E2F1, MYC, DUSP6, POU2F1, RUNX1, SPI1, CEBPAB and CEBPE all set to 1, while the rest of the nodes were set to 0.

# %%
# Convert each model variant to MaBoSS format and store in maboss_models dict.
maboss_models = {name: biolqm.to_maboss(model) for name, model in lqm_models.items()}

# %%
# %%time  

# Stochastic simulations for the two EZH2 perturbation conditions + control, under physiological and pharmacological levels of Retinoic Acid.

import matplotlib.pyplot as plt

# Define the visualisation (color-node) pairs.
node_colors = {
    "E2F1": "#84F24C",
    "CDKN1A": "#FD817B",
    "CDKN1B": "#FD817B",
    "MYC": "#84F24C",
    "CEBPAB": "#FFF056",
    "SPI1": "#FFF056",
    "EZH2": "#FFCC33",
    "PLZF_RARA": "#FF0000",
    "CEBPAB -- CDKN1B": "#FFF056",
    "PLZF_RARA -- E2F1 -- EZH2": "#84F24C"
}

# Define the outputs
outputs = ["E2F1", "SPI1", "EZH2", "PLZF_RARA"]

# Define the nodes initial states
maboss_istates = {'Physiological RA (RA=1)' : [
    "RA_b1", "PLZF_RARAg", "RARA", "PML", "PLZF", "USP37", 
    "CoAct_COMP", "EZH2", "PRC2", "CoRep_COMP", "CDKN2D", 
    "RB1", "SKP2", "MDM2", "CAK", "CCNA2", "CCND1", 
    "CCNE2", "CDK4_6", "CDK2", "E2F1", "MYC", 
    "DUSP6", "POU2F1", "RUNX1", "SPI1", "CEBPAB", 
    "CEBPE"
], 'Pharmacological RA (RA=2)' : [
    "RA_b1", "RA_b2", "PLZF_RARAg", "RARA", "PML", "PLZF", "USP37", 
    "CoAct_COMP", "EZH2", "PRC2", "CoRep_COMP", "CDKN2D", 
    "RB1", "SKP2", "MDM2", "CAK", "CCNA2", "CCND1", 
    "CCNE2", "CDK4_6", "CDK2", "E2F1", "MYC", 
    "DUSP6", "POU2F1", "RUNX1", "SPI1", "CEBPAB", 
    "CEBPE"
]}

for name, istate in maboss_istates.items():
    
    # Loop over the models
    for k, v in maboss_models.items():
        # Apply node colors
        v.palette.update(node_colors)
    
        # Set outputs
        v.network.set_output(outputs)

        # Set the initial states for the nodes
        maboss.set_nodes_istate(v, istate, [0, 1])
    
        # Update parameters and run the simulation
        v.update_parameters(max_time=30)
        simres = v.run()
        
        # Plotting results
        simres.plot_piechart()
        plt.title(k+' '+name)
    
        simres.plot_trajectory()
        plt.title(k+' '+name)
    
        simres.plot_node_trajectory()
        plt.title(k+' '+name)
    
        simres.plot_entropy_trajectory()
        plt.title(k+' '+name)
# Out:
# Warning, node RA_b1 was previously bound to other nodes
# Warning, node RA_b1 was previously bound to other nodes
# Warning, node RA_b1 was previously bound to other nodes
# /opt/conda/lib/python3.11/site-packages/maboss/results/baseresult.py:102: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   _, axes = plt.subplots(1,1)
# CPU times: user 4.33 s, sys: 113 ms, total: 4.44 s
# Wall time: 1min 20s

# %% [markdown]
# The average results obtained over 10 000 MaBoSS simulations for each of the three conditions under physiological and pharmacological levels of RA are displayed.
# The time-plots show the evolution of the mean values of representative cell markers and cell states in time.
# The pie charts display the proportions of simulations leading to each stable state at the end of these simulations (i.e. at time 30, arbitrary units).
# The last plots display the evolution of the state entropy (H) and of the transition entropy (TH) over time.
#
#
# From the comparison of the control with the EZH2:PRC2%0 case, we can conclude that the suppression of the influence of EZH2 onto PCR2 has a very marginal impact on cell fate decision.
# In contrast, the full knockout of EZH2 (EZH2 KO) has a drastic impact on cell fate decision, eliminating the proliferative attractor.

# %% [markdown]
# # Comprehensive perturbation analysis with MaBoSS
# In order to determine which nodes significantly impact cell fate decision, we can further use MaBoSS to perform stochastic simulations for gain-of-function and loss-of-function of selected nodes.
# Here also, a state representing the granulocyte-monocyte progenitor stage was used as initial state, with RA set to 2, PLZF_RARAg, RARA, PML, PLZF, USP37, CoAct_COMP, EZH2, PRC2, CoRep_COMP, CDKN2D, RB1, SKP2, MDM2, CAK, CCNA2, CCND1, CCNE2, CDK4_6, CDK2, E2F1, MYC, DUSP6, POU2F1, RUNX1, SPI1, CEBPAB, CEBPE all set to 1, while the rest of the nodes were set to 0.

# %%
# %%time  

# The calculations performed in this cell take around twenty mins on an Apple M1 Pro, 32 GB.
# Comprehensive perturbation analysis with MaBoSS for the identification of nodes affecting the proportions of Differentiation and Proliferation phenotypes.

import matplotlib.pyplot as plt

maboss.set_nodes_istate(maboss_models['No perturbation'], ["RA_b1", "RA_b2", "PLZF_RARAg", "RARA", "PML", "PLZF", "USP37", "CoAct_COMP", "EZH2", "PRC2", "CoRep_COMP", "CDKN2D", "RB1", "SKP2", "MDM2", "CAK", "CCNA2", "CCND1", "CCNE2", "CDK4_6", "CDK2", "E2F1", "MYC", "DUSP6", "POU2F1", "RUNX1", "SPI1", "CEBPAB", "CEBPE"], [0, 1])
maboss_models['No perturbation'].network.set_output(["E2F1", "SPI1"])

sensitivity_analysis_nodes = ['RARA', 'PML','PLZF', 'PLZF_RARA', 'USP37', 'CoAct_COMP', 'EZH2', 'PRC2', 'CoRep_COMP', 'CDKN1A', 'CDKN1B', 'CDKN2D', 'RB1', 'TP53', 'SKP2', 'MDM2', 'CAK', 'CCNA2', 'CCND1', 'CCNE2', 'CDK4_6', 'CDK2', 'E2F1', 'MYC', 'POU2F1', 'GATA2', 'SPI1', 'CEBPAB', 'CEBPE']
sensitivity = maboss.pipelines.simulate_single_mutants(maboss_models['No perturbation'], list_nodes=sensitivity_analysis_nodes, sign='BOTH', cmaboss=False)
for cond in sensitivity:
    sensitivity[cond].plot_piechart()
    plt.title(cond)
    
# activate these lines to plot the trajectories    
    #sensitivity[cond].plot_trajectory()
    #plt.title(cond)
    #sensitivity[cond].plot_node_trajectory()
    #plt.title(cond)
# Out:
# /opt/conda/lib/python3.11/site-packages/maboss/results/baseresult.py:102: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   _, axes = plt.subplots(1,1)
# CPU times: user 7.32 s, sys: 657 ms, total: 7.97 s
# Wall time: 11min 27s

# %% [markdown]
# This analysis points to key nodes of the network whose perturbations, i.e. gain-of-function (GOF) or loss-of-function (LOF), affect the probability to reach the differentiated or proliferative attractors.
#
# Perturbations blocking the reachability towards the differentiated attractor:
# * PLZF_RARA GOF
# * RARA LOF
# * SPI1 LOF
#
#
#
# Perturbations blocking the reachability towards the proliferative attractor:
# * CDKN1A GOF
# * CDKN1B GOF
# * RB1 GOF
# * CEBPAB GOF
# * PLZF_RARA LOF
# * USP37 LOF
# * EZH2 LOF
# * CAK LOF
# * E2F1 LOF
# * MYC LOF
#
# These simulation results are coherent with published experimental observations and point to potential targets for combinatorial therapies.
# Tuning of the initial states or of the transition rates used in MaBoSS simulations can be performed to further characterised the potential impacts of selected pertubations in cell fate decisions.

# %% [markdown]
# # Parameter sensitivity analysis with MaBoSS

# %% [markdown]
# We can further use MaBoSS to perform stochastic simulations considering variations in the activation and deactivation rates of each node.
# We use three decreasing and three increasing factors (001, 0.01, 0.1, 1, 10, 100, 1000) for each up and down transition rates of model internal nodes.
# Here also, a state representing the granulocyte-monocyte progenitor stage was used as initial state, with RA set to 2, PLZF_RARAg, RARA, PML, PLZF, USP37, CoAct_COMP, EZH2, PRC2, CoRep_COMP, CDKN2D, RB1, SKP2, MDM2, CAK, CCNA2, CCND1, CCNE2, CDK4_6, CDK2, E2F1, MYC, DUSP6, POU2F1, RUNX1, SPI1, CEBPAB, CEBPE all set to 1, while the rest of the nodes were set to 0.

# %%
# Definition of the simulation parameters.
maboss.set_nodes_istate(maboss_models['No perturbation'], ["RA_b1", "RA_b2", "PLZF_RARAg", "RARA", "PML", "PLZF", "USP37", "CoAct_COMP", "EZH2", "PRC2", "CoRep_COMP", "CDKN2D", "RB1", "SKP2", "MDM2", "CAK", "CCNA2", "CCND1", "CCNE2", "CDK4_6", "CDK2", "E2F1", "MYC", "DUSP6", "POU2F1", "RUNX1", "SPI1", "CEBPAB", "CEBPE"], [0, 1])
maboss_models['No perturbation'].network.set_output(["E2F1", "SPI1"])
E2F1='E2F1'
SPI1='SPI1'
maboss_models['No perturbation'].palette[E2F1] = "#84F24C"
maboss_models['No perturbation'].palette[SPI1] = "#FFF056"

# Definition of a long simulation time to allow the system to reach equilibrium.
# maboss_models['No perturbation'].update_parameters(max_time=20000)

# Activate these lines alternatively to get a shorter (faster) simulation    
maboss_models['No perturbation'].update_parameters(max_time=30)


def simulate_single_mutants_rates(model, list_nodes=[], rates=[], directions=[], cmaboss=False):
    """
        Simulates a batch of single mutants in rates and return an array of results

        :param model: the model on which to perform the simulations
        :param list_nodes: the node(s) which are to be mutated (default: all nodes)
        :param rates: which rate mutation to perform. Any list of floats. ([0.001, 0.01, 0.1, 1, 10, 100, 1000] default)
        :param direction: which direction. "up", or "down". ("up" and "down" as default)  
    """ 
    
    if len(list_nodes) == 0:
        list_nodes = list(model.network.keys())
     
    list_single_mutants = []
    default_directions = ['up', 'down']
    default_rates = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
    if len(rates) == 0:
        rates = default_rates
    if len(directions) ==0:
        directions = default_directions
    for direction in directions:
        for node in list_nodes:
            list_single_mutants += [(node, direction, rate) for rate in rates]

    res = {}
    for single_mutant in list_single_mutants:
        t_model = model.copy()    
        if single_mutant[1]== 'up':
            t_model.param['$u_'+single_mutant[0]] = single_mutant[2]
        if single_mutant[1]== 'down':
            t_model.param['$d_'+single_mutant[0]] = single_mutant[2]
        res.update({single_mutant: t_model.run(cmaboss=cmaboss)})
        
    return res

# %%
# %%time

# Stochastic simulations with variations in the activation and deactivation rates of each node (excepting input nodes).
# The calculations performed in this cell take around two hours on an Apple M1 Pro, 32 GB.

all_results = simulate_single_mutants_rates(maboss_models['No perturbation'], list_nodes=[], rates=[], cmaboss=False)
all_results
# Out:
# CPU times: user 5.07 s, sys: 4.83 s, total: 9.89 s
# Wall time: 1h 46min 29s
# {('RA_b1', 'up', 0.001): <maboss.result.Result at 0x2aab749fb250>,
#  ('RA_b1', 'up', 0.01): <maboss.result.Result at 0x2aab6bec8b90>,
#  ('RA_b1', 'up', 0.1): <maboss.result.Result at 0x2aab742e5450>,
#  ('RA_b1', 'up', 1): <maboss.result.Result at 0x2aab7644a7d0>,
#  ('RA_b1', 'up', 10): <maboss.result.Result at 0x2aab747de6d0>,
#  ('RA_b1', 'up', 100): <maboss.result.Result at 0x2aab76549650>,
#  ('RA_b1', 'up', 1000): <maboss.result.Result at 0x2aab74ab5a50>,
#  ('RA_b2', 'up', 0.001): <maboss.result.Result at 0x2aab74b40250>,
#  ('RA_b2', 'up', 0.01): <maboss.result.Result at 0x2aab742f2d90>,
#  ('RA_b2', 'up', 0.1): <maboss.result.Result at 0x2aab742e67d0>,
#  ('RA_b2', 'up', 1): <maboss.result.Result at 0x2aab74c53a50>,
#  ('RA_b2', 'up', 10): <maboss.result.Result at 0x2aab742e6cd0>,
#  ('RA_b2', 'up', 100): <maboss.result.Result at 0x2aab746b4590>,
#  ('RA_b2', 'up', 1000): <maboss.result.Result at 0x2aab746974d0>,
#  ('PML_RARAg', 'up', 0.001): <maboss.result.Result at 0x2aab74a67310>,
#  ('PML_RARAg', 'up', 0.01): <maboss.result.Result at 0x2aab7425ded0>,
#  ('PML_RARAg', 'up', 0.1): <maboss.result.Result at 0x2aab74bb3510>,
#  ('PML_RARAg', 'up', 1): <maboss.result.Result at 0x2aab742e7150>,
#  ('PML_RARAg', 'up', 10): <maboss.result.Result at 0x2aab74a74dd0>,
#  ('PML_RARAg', 'up', 100): <maboss.result.Result at 0x2aab75d69590>,
#  ('PML_RARAg', 'up', 1000): <maboss.result.Result at 0x2aab75fc1310>,
#  ('PLZF_RARAg', 'up', 0.001): <maboss.result.Result at 0x2aab742f88d0>,
#  ('PLZF_RARAg', 'up', 0.01): <maboss.result.Result at 0x2aab74625b10>,
#  ('PLZF_RARAg', 'up', 0.1): <maboss.result.Result at 0x2aab7425d850>,
#  ('PLZF_RARAg', 'up', 1): <maboss.result.Result at 0x2aaaf447b290>,
#  ('PLZF_RARAg', 'up', 10): <maboss.result.Result at 0x2aab74c37790>,
#  ('PLZF_RARAg', 'up', 100): <maboss.result.Result at 0x2aab74392350>,
#  ('PLZF_RARAg', 'up', 1000): <maboss.result.Result at 0x2aab74a5ba10>,
#  ('RARA', 'up', 0.001): <maboss.result.Result at 0x2aab742e4f10>,
#  ('RARA', 'up', 0.01): <maboss.result.Result at 0x2aab74ac1810>,
#  ('RARA', 'up', 0.1): <maboss.result.Result at 0x2aab74a5bb50>,
#  ('RARA', 'up', 1): <maboss.result.Result at 0x2aab74aa4c50>,
#  ('RARA', 'up', 10): <maboss.result.Result at 0x2aab74316110>,
#  ('RARA', 'up', 100): <maboss.result.Result at 0x2aab74622a90>,
#  ('RARA', 'up', 1000): <maboss.result.Result at 0x2aab742fabd0>,
#  ('PML', 'up', 0.001): <maboss.result.Result at 0x2aab74316f90>,
#  ('PML', 'up', 0.01): <maboss.result.Result at 0x2aab742dc890>,
#  ('PML', 'up', 0.1): <maboss.result.Result at 0x2aab74304950>,
#  ('PML', 'up', 1): <maboss.result.Result at 0x2aab74adb250>,
#  ('PML', 'up', 10): <maboss.result.Result at 0x2aab6bf97e50>,
#  ('PML', 'up', 100): <maboss.result.Result at 0x2aab74316190>,
#  ('PML', 'up', 1000): <maboss.result.Result at 0x2aab74ab6590>,
#  ('PML_RARA', 'up', 0.001): <maboss.result.Result at 0x2aab74aa6910>,
#  ('PML_RARA', 'up', 0.01): <maboss.result.Result at 0x2aab6c1b4210>,
#  ('PML_RARA', 'up', 0.1): <maboss.result.Result at 0x2aab74c08410>,
#  ('PML_RARA', 'up', 1): <maboss.result.Result at 0x2aab74696450>,
#  ('PML_RARA', 'up', 10): <maboss.result.Result at 0x2aab747f4410>,
#  ('PML_RARA', 'up', 100): <maboss.result.Result at 0x2aab765cfd10>,
#  ('PML_RARA', 'up', 1000): <maboss.result.Result at 0x2aab74317190>,
#  ('PLZF', 'up', 0.001): <maboss.result.Result at 0x2aab742e5250>,
#  ('PLZF', 'up', 0.01): <maboss.result.Result at 0x2aab742e7050>,
#  ('PLZF', 'up', 0.1): <maboss.result.Result at 0x2aab74a5a0d0>,
#  ('PLZF', 'up', 1): <maboss.result.Result at 0x2aab763f7790>,
#  ('PLZF', 'up', 10): <maboss.result.Result at 0x2aab7458bb90>,
#  ('PLZF', 'up', 100): <maboss.result.Result at 0x2aab742f1d90>,
#  ('PLZF', 'up', 1000): <maboss.result.Result at 0x2aab748961d0>,
#  ('PLZF_RARA', 'up', 0.001): <maboss.result.Result at 0x2aab76004a50>,
#  ('PLZF_RARA', 'up', 0.01): <maboss.result.Result at 0x2aab74896090>,
#  ('PLZF_RARA', 'up', 0.1): <maboss.result.Result at 0x2aab746ac590>,
#  ('PLZF_RARA', 'up', 1): <maboss.result.Result at 0x2aab742dcd90>,
#  ('PLZF_RARA', 'up', 10): <maboss.result.Result at 0x2aab742e5f50>,
#  ('PLZF_RARA', 'up', 100): <maboss.result.Result at 0x2aab74c36d10>,
#  ('PLZF_RARA', 'up', 1000): <maboss.result.Result at 0x2aab7425f8d0>,
#  ('USP37', 'up', 0.001): <maboss.result.Result at 0x2aab7483cb50>,
#  ('USP37', 'up', 0.01): <maboss.result.Result at 0x2aab742e7dd0>,
#  ('USP37', 'up', 0.1): <maboss.result.Result at 0x2aab7493be90>,
#  ('USP37', 'up', 1): <maboss.result.Result at 0x2aab7433ab10>,
#  ('USP37', 'up', 10): <maboss.result.Result at 0x2aab7433a490>,
#  ('USP37', 'up', 100): <maboss.result.Result at 0x2aab74315410>,
#  ('USP37', 'up', 1000): <maboss.result.Result at 0x2aab74aa5610>,
#  ('CoAct_COMP', 'up', 0.001): <maboss.result.Result at 0x2aab7433b2d0>,
#  ('CoAct_COMP', 'up', 0.01): <maboss.result.Result at 0x2aab7433b550>,
#  ('CoAct_COMP', 'up', 0.1): <maboss.result.Result at 0x2aab74305a90>,
#  ('CoAct_COMP', 'up', 1): <maboss.result.Result at 0x2aab7425d790>,
#  ('CoAct_COMP', 'up', 10): <maboss.result.Result at 0x2aab6c16cc50>,
#  ('CoAct_COMP', 'up', 100): <maboss.result.Result at 0x2aab74338150>,
#  ('CoAct_COMP', 'up', 1000): <maboss.result.Result at 0x2aab74a5b990>,
#  ('EZH2', 'up', 0.001): <maboss.result.Result at 0x2aab7433a950>,
#  ('EZH2', 'up', 0.01): <maboss.result.Result at 0x2aab74b239d0>,
#  ('EZH2', 'up', 0.1): <maboss.result.Result at 0x2aab7433bf90>,
#  ('EZH2', 'up', 1): <maboss.result.Result at 0x2aab74ac3dd0>,
#  ('EZH2', 'up', 10): <maboss.result.Result at 0x2aab74c36e50>,
#  ('EZH2', 'up', 100): <maboss.result.Result at 0x2aab74a77dd0>,
#  ('EZH2', 'up', 1000): <maboss.result.Result at 0x2aab74aa7f50>,
#  ('PRC2', 'up', 0.001): <maboss.result.Result at 0x2aab7425ee10>,
#  ('PRC2', 'up', 0.01): <maboss.result.Result at 0x2aab74c61b10>,
#  ('PRC2', 'up', 0.1): <maboss.result.Result at 0x2aab749c4690>,
#  ('PRC2', 'up', 1): <maboss.result.Result at 0x2aab74339850>,
#  ('PRC2', 'up', 10): <maboss.result.Result at 0x2aab74305890>,
#  ('PRC2', 'up', 100): <maboss.result.Result at 0x2aab743394d0>,
#  ('PRC2', 'up', 1000): <maboss.result.Result at 0x2aab7425e690>,
#  ('CoRep_COMP', 'up', 0.001): <maboss.result.Result at 0x2aab7631db90>,
#  ('CoRep_COMP', 'up', 0.01): <maboss.result.Result at 0x2aaaf4493250>,
#  ('CoRep_COMP', 'up', 0.1): <maboss.result.Result at 0x2aab743391d0>,
#  ('CoRep_COMP', 'up', 1): <maboss.result.Result at 0x2aab7433b250>,
#  ('CoRep_COMP', 'up', 10): <maboss.result.Result at 0x2aab74ab0d10>,
#  ('CoRep_COMP', 'up', 100): <maboss.result.Result at 0x2aab742dc650>,
#  ('CoRep_COMP', 'up', 1000): <maboss.result.Result at 0x2aab7433bc50>,
#  ('CDKN1A', 'up', 0.001): <maboss.result.Result at 0x2aab74306a90>,
#  ('CDKN1A', 'up', 0.01): <maboss.result.Result at 0x2aab7433a010>,
#  ('CDKN1A', 'up', 0.1): <maboss.result.Result at 0x2aab74894410>,
#  ('CDKN1A', 'up', 1): <maboss.result.Result at 0x2aab74338350>,
#  ('CDKN1A', 'up', 10): <maboss.result.Result at 0x2aab7433bcd0>,
#  ('CDKN1A', 'up', 100): <maboss.result.Result at 0x2aab7433bb10>,
#  ('CDKN1A', 'up', 1000): <maboss.result.Result at 0x2aab742f0090>,
#  ('CDKN1B', 'up', 0.001): <maboss.result.Result at 0x2aab7433b450>,
#  ('CDKN1B', 'up', 0.01): <maboss.result.Result at 0x2aab74a59f90>,
#  ('CDKN1B', 'up', 0.1): <maboss.result.Result at 0x2aab74339910>,
#  ('CDKN1B', 'up', 1): <maboss.result.Result at 0x2aab746976d0>,
#  ('CDKN1B', 'up', 10): <maboss.result.Result at 0x2aab7469e9d0>,
#  ('CDKN1B', 'up', 100): <maboss.result.Result at 0x2aab760d7750>,
#  ('CDKN1B', 'up', 1000): <maboss.result.Result at 0x2aab7433a4d0>,
#  ('CDKN2D', 'up', 0.001): <maboss.result.Result at 0x2aab746b4c90>,
#  ('CDKN2D', 'up', 0.01): <maboss.result.Result at 0x2aab7433b610>,
#  ('CDKN2D', 'up', 0.1): <maboss.result.Result at 0x2aab742f3e10>,
#  ('CDKN2D', 'up', 1): <maboss.result.Result at 0x2aab7433bbd0>,
#  ('CDKN2D', 'up', 10): <maboss.result.Result at 0x2aab74896490>,
#  ('CDKN2D', 'up', 100): <maboss.result.Result at 0x2aab7433a150>,
#  ('CDKN2D', 'up', 1000): <maboss.result.Result at 0x2aab746b4b10>,
#  ('RB1', 'up', 0.001): <maboss.result.Result at 0x2aab74338450>,
#  ('RB1', 'up', 0.01): <maboss.result.Result at 0x2aab74b21710>,
#  ('RB1', 'up', 0.1): <maboss.result.Result at 0x2aab74338a90>,
#  ('RB1', 'up', 1): <maboss.result.Result at 0x2aab74a5bc90>,
#  ('RB1', 'up', 10): <maboss.result.Result at 0x2aab74339190>,
#  ('RB1', 'up', 100): <maboss.result.Result at 0x2aab742debd0>,
#  ('RB1', 'up', 1000): <maboss.result.Result at 0x2aab7433a650>,
#  ('TP53', 'up', 0.001): <maboss.result.Result at 0x2aab742de010>,
#  ('TP53', 'up', 0.01): <maboss.result.Result at 0x2aab74339cd0>,
#  ('TP53', 'up', 0.1): <maboss.result.Result at 0x2aab74897b90>,
#  ('TP53', 'up', 1): <maboss.result.Result at 0x2aab7433b210>,
#  ('TP53', 'up', 10): <maboss.result.Result at 0x2aab74a66950>,
#  ('TP53', 'up', 100): <maboss.result.Result at 0x2aab7433b910>,
#  ('TP53', 'up', 1000): <maboss.result.Result at 0x2aab742f0410>,
#  ('SKP2', 'up', 0.001): <maboss.result.Result at 0x2aab742f2cd0>,
#  ('SKP2', 'up', 0.01): <maboss.result.Result at 0x2aab74a76650>,
#  ('SKP2', 'up', 0.1): <maboss.result.Result at 0x2aab742fae10>,
#  ('SKP2', 'up', 1): <maboss.result.Result at 0x2aab74404190>,
#  ('SKP2', 'up', 10): <maboss.result.Result at 0x2aab742f9f10>,
#  ('SKP2', 'up', 100): <maboss.result.Result at 0x2aab7433b350>,
#  ('SKP2', 'up', 1000): <maboss.result.Result at 0x2aab74ab2350>,
#  ('MDM2', 'up', 0.001): <maboss.result.Result at 0x2aab74338250>,
#  ('MDM2', 'up', 0.01): <maboss.result.Result at 0x2aab747f7610>,
#  ('MDM2', 'up', 0.1): <maboss.result.Result at 0x2aab7433b010>,
#  ('MDM2', 'up', 1): <maboss.result.Result at 0x2aab7433a990>,
#  ('MDM2', 'up', 10): <maboss.result.Result at 0x2aab742e7b90>,
#  ('MDM2', 'up', 100): <maboss.result.Result at 0x2aab7433b690>,
#  ('MDM2', 'up', 1000): <maboss.result.Result at 0x2aab74a5a610>,
#  ('CAK', 'up', 0.001): <maboss.result.Result at 0x2aab746c7fd0>,
#  ('CAK', 'up', 0.01): <maboss.result.Result at 0x2aab7673ae90>,
#  ('CAK', 'up', 0.1): <maboss.result.Result at 0x2aab74338890>,
#  ('CAK', 'up', 1): <maboss.result.Result at 0x2aab7433bad0>,
#  ('CAK', 'up', 10): <maboss.result.Result at 0x2aab7433b790>,
#  ('CAK', 'up', 100): <maboss.result.Result at 0x2aab74ac0750>,
#  ('CAK', 'up', 1000): <maboss.result.Result at 0x2aab74b236d0>,
#  ('CCNA2', 'up', 0.001): <maboss.result.Result at 0x2aab74b22450>,
#  ('CCNA2', 'up', 0.01): <maboss.result.Result at 0x2aab6b91bdd0>,
#  ('CCNA2', 'up', 0.1): <maboss.result.Result at 0x2aab76370990>,
#  ('CCNA2', 'up', 1): <maboss.result.Result at 0x2aab7433b810>,
#  ('CCNA2', 'up', 10): <maboss.result.Result at 0x2aab74c52550>,
#  ('CCNA2', 'up', 100): <maboss.result.Result at 0x2aab745e3050>,
#  ('CCNA2', 'up', 1000): <maboss.result.Result at 0x2aab7635bad0>,
#  ('CCND1', 'up', 0.001): <maboss.result.Result at 0x2aab7482a7d0>,
#  ('CCND1', 'up', 0.01): <maboss.result.Result at 0x2aab749dbf50>,
#  ('CCND1', 'up', 0.1): <maboss.result.Result at 0x2aab74c545d0>,
#  ('CCND1', 'up', 1): <maboss.result.Result at 0x2aab74307090>,
#  ('CCND1', 'up', 10): <maboss.result.Result at 0x2aab74697910>,
#  ('CCND1', 'up', 100): <maboss.result.Result at 0x2aab74529510>,
#  ('CCND1', 'up', 1000): <maboss.result.Result at 0x2aab76168610>,
#  ('CCNE2', 'up', 0.001): <maboss.result.Result at 0x2aab7433b7d0>,
#  ('CCNE2', 'up', 0.01): <maboss.result.Result at 0x2aab74312b50>,
#  ('CCNE2', 'up', 0.1): <maboss.result.Result at 0x2aab74338490>,
#  ('CCNE2', 'up', 1): <maboss.result.Result at 0x2aab742cfd50>,
#  ('CCNE2', 'up', 10): <maboss.result.Result at 0x2aab7433a8d0>,
#  ('CCNE2', 'up', 100): <maboss.result.Result at 0x2aab74312650>,
#  ('CCNE2', 'up', 1000): <maboss.result.Result at 0x2aab74c0b6d0>,
#  ('CDK4_6', 'up', 0.001): <maboss.result.Result at 0x2aab747f4710>,
#  ('CDK4_6', 'up', 0.01): <maboss.result.Result at 0x2aab742fa190>,
#  ('CDK4_6', 'up', 0.1): <maboss.result.Result at 0x2aab762a09d0>,
#  ('CDK4_6', 'up', 1): <maboss.result.Result at 0x2aab74a38d90>,
#  ('CDK4_6', 'up', 10): <maboss.result.Result at 0x2aab742f8150>,
#  ('CDK4_6', 'up', 100): <maboss.result.Result at 0x2aab76188210>,
#  ('CDK4_6', 'up', 1000): <maboss.result.Result at 0x2aab74aa48d0>,
#  ('CDK2', 'up', 0.001): <maboss.result.Result at 0x2aab7433bd10>,
#  ('CDK2', 'up', 0.01): <maboss.result.Result at 0x2aab74304e50>,
#  ('CDK2', 'up', 0.1): <maboss.result.Result at 0x2aab74b90110>,
#  ('CDK2', 'up', 1): <maboss.result.Result at 0x2aab74338e10>,
#  ('CDK2', 'up', 10): <maboss.result.Result at 0x2aab7433abd0>,
#  ('CDK2', 'up', 100): <maboss.result.Result at 0x2aab74339750>,
#  ('CDK2', 'up', 1000): <maboss.result.Result at 0x2aab74893090>,
#  ('E2F1', 'up', 0.001): <maboss.result.Result at 0x2aab74a694d0>,
#  ('E2F1', 'up', 0.01): <maboss.result.Result at 0x2aab74a59610>,
#  ('E2F1', 'up', 0.1): <maboss.result.Result at 0x2aab7433b850>,
#  ('E2F1', 'up', 1): <maboss.result.Result at 0x2aab74312510>,
#  ('E2F1', 'up', 10): <maboss.result.Result at 0x2aab74740790>,
#  ('E2F1', 'up', 100): <maboss.result.Result at 0x2aab7425d6d0>,
#  ('E2F1', 'up', 1000): <maboss.result.Result at 0x2aab76121110>,
#  ('MYC', 'up', 0.001): <maboss.result.Result at 0x2aab74ac0c50>,
#  ('MYC', 'up', 0.01): <maboss.result.Result at 0x2aab74430b50>,
#  ('MYC', 'up', 0.1): <maboss.result.Result at 0x2aab6c16db10>,
#  ('MYC', 'up', 1): <maboss.result.Result at 0x2aab6c0638d0>,
#  ('MYC', 'up', 10): <maboss.result.Result at 0x2aab74313d10>,
#  ('MYC', 'up', 100): <maboss.result.Result at 0x2aab74a639d0>,
#  ('MYC', 'up', 1000): <maboss.result.Result at 0x2aab743122d0>,
#  ('DUSP6', 'up', 0.001): <maboss.result.Result at 0x2aab7433a510>,
#  ('DUSP6', 'up', 0.01): <maboss.result.Result at 0x2aab74313a50>,
#  ('DUSP6', 'up', 0.1): <maboss.result.Result at 0x2aab74a63310>,
#  ('DUSP6', 'up', 1): <maboss.result.Result at 0x2aab74312f90>,
#  ('DUSP6', 'up', 10): <maboss.result.Result at 0x2aab74338cd0>,
#  ('DUSP6', 'up', 100): <maboss.result.Result at 0x2aab74310910>,
#  ('DUSP6', 'up', 1000): <maboss.result.Result at 0x2aab743380d0>,
#  ('POU2F1', 'up', 0.001): <maboss.result.Result at 0x2aab74311690>,
#  ('POU2F1', 'up', 0.01): <maboss.result.Result at 0x2aab7433ac10>,
#  ('POU2F1', 'up', 0.1): <maboss.result.Result at 0x2aab74312d90>,
#  ('POU2F1', 'up', 1): <maboss.result.Result at 0x2aab74594710>,
#  ('POU2F1', 'up', 10): <maboss.result.Result at 0x2aab74310090>,
#  ('POU2F1', 'up', 100): <maboss.result.Result at 0x2aab7433b390>,
#  ('POU2F1', 'up', 1000): <maboss.result.Result at 0x2aab74312950>,
#  ('GATA2', 'up', 0.001): <maboss.result.Result at 0x2aab7433bed0>,
#  ('GATA2', 'up', 0.01): <maboss.result.Result at 0x2aab74311b50>,
#  ('GATA2', 'up', 0.1): <maboss.result.Result at 0x2aab743138d0>,
#  ('GATA2', 'up', 1): <maboss.result.Result at 0x2aab74310c90>,
#  ('GATA2', 'up', 10): <maboss.result.Result at 0x2aab743118d0>,
#  ('GATA2', 'up', 100): <maboss.result.Result at 0x2aab743101d0>,
#  ('GATA2', 'up', 1000): <maboss.result.Result at 0x2aab74313c10>,
#  ('RUNX1', 'up', 0.001): <maboss.result.Result at 0x2aab74313490>,
#  ('RUNX1', 'up', 0.01): <maboss.result.Result at 0x2aab742e4bd0>,
#  ('RUNX1', 'up', 0.1): <maboss.result.Result at 0x2aab74310a90>,
#  ('RUNX1', 'up', 1): <maboss.result.Result at 0x2aab74313810>,
#  ('RUNX1', 'up', 10): <maboss.result.Result at 0x2aab743128d0>,
#  ('RUNX1', 'up', 100): <maboss.result.Result at 0x2aab74312890>,
#  ('RUNX1', 'up', 1000): <maboss.result.Result at 0x2aab74312090>,
#  ('SPI1', 'up', 0.001): <maboss.result.Result at 0x2aab74312290>,
#  ('SPI1', 'up', 0.01): <maboss.result.Result at 0x2aab74311790>,
#  ('SPI1', 'up', 0.1): <maboss.result.Result at 0x2aab74312a90>,
#  ('SPI1', 'up', 1): <maboss.result.Result at 0x2aab74310450>,
#  ('SPI1', 'up', 10): <maboss.result.Result at 0x2aab74313d50>,
#  ('SPI1', 'up', 100): <maboss.result.Result at 0x2aab74313e10>,
#  ('SPI1', 'up', 1000): <maboss.result.Result at 0x2aab74310d90>,
#  ('CEBPAB', 'up', 0.001): <maboss.result.Result at 0x2aab74313350>,
#  ('CEBPAB', 'up', 0.01): <maboss.result.Result at 0x2aab743102d0>,
#  ('CEBPAB', 'up', 0.1): <maboss.result.Result at 0x2aab74311090>,
#  ('CEBPAB', 'up', 1): <maboss.result.Result at 0x2aab74313f90>,
#  ('CEBPAB', 'up', 10): <maboss.result.Result at 0x2aab74310dd0>,
#  ('CEBPAB', 'up', 100): <maboss.result.Result at 0x2aab743139d0>,
#  ('CEBPAB', 'up', 1000): <maboss.result.Result at 0x2aab74310e50>,
#  ('CEBPE', 'up', 0.001): <maboss.result.Result at 0x2aab74311f50>,
#  ('CEBPE', 'up', 0.01): <maboss.result.Result at 0x2aab743129d0>,
#  ('CEBPE', 'up', 0.1): <maboss.result.Result at 0x2aab74311dd0>,
#  ('CEBPE', 'up', 1): <maboss.result.Result at 0x2aab74312350>,
#  ('CEBPE', 'up', 10): <maboss.result.Result at 0x2aab74313390>,
#  ('CEBPE', 'up', 100): <maboss.result.Result at 0x2aab74312ad0>,
#  ('CEBPE', 'up', 1000): <maboss.result.Result at 0x2aab74313cd0>,
#  ('RARB', 'up', 0.001): <maboss.result.Result at 0x2aab7601f310>,
#  ('RARB', 'up', 0.01): <maboss.result.Result at 0x2aab743134d0>,
#  ('RARB', 'up', 0.1): <maboss.result.Result at 0x2aab743107d0>,
#  ('RARB', 'up', 1): <maboss.result.Result at 0x2aab74311610>,
#  ('RARB', 'up', 10): <maboss.result.Result at 0x2aab743113d0>,
#  ('RARB', 'up', 100): <maboss.result.Result at 0x2aab74312990>,
#  ('RARB', 'up', 1000): <maboss.result.Result at 0x2aab74311810>,
#  ('RA_b1', 'down', 0.001): <maboss.result.Result at 0x2aab764e7c90>,
#  ('RA_b1', 'down', 0.01): <maboss.result.Result at 0x2aab74312690>,
#  ('RA_b1', 'down', 0.1): <maboss.result.Result at 0x2aab74313dd0>,
#  ('RA_b1', 'down', 1): <maboss.result.Result at 0x2aab74311350>,
#  ('RA_b1', 'down', 10): <maboss.result.Result at 0x2aab74312b90>,
#  ('RA_b1', 'down', 100): <maboss.result.Result at 0x2aab74252e10>,
#  ('RA_b1', 'down', 1000): <maboss.result.Result at 0x2aab74312dd0>,
#  ('RA_b2', 'down', 0.001): <maboss.result.Result at 0x2aab742529d0>,
#  ('RA_b2', 'down', 0.01): <maboss.result.Result at 0x2aab74311b10>,
#  ('RA_b2', 'down', 0.1): <maboss.result.Result at 0x2aab74253590>,
#  ('RA_b2', 'down', 1): <maboss.result.Result at 0x2aab74313590>,
#  ('RA_b2', 'down', 10): <maboss.result.Result at 0x2aab74253090>,
#  ('RA_b2', 'down', 100): <maboss.result.Result at 0x2aab74311ad0>,
#  ('RA_b2', 'down', 1000): <maboss.result.Result at 0x2aab74250b10>,
#  ('PML_RARAg', 'down', 0.001): <maboss.result.Result at 0x2aab74311410>,
#  ('PML_RARAg', 'down', 0.01): <maboss.result.Result at 0x2aab74252310>,
#  ('PML_RARAg', 'down', 0.1): <maboss.result.Result at 0x2aab74251090>,
#  ('PML_RARAg', 'down', 1): <maboss.result.Result at 0x2aab74251790>,
#  ('PML_RARAg', 'down', 10): <maboss.result.Result at 0x2aab74252ad0>,
#  ('PML_RARAg', 'down', 100): <maboss.result.Result at 0x2aab742532d0>,
#  ('PML_RARAg', 'down', 1000): <maboss.result.Result at 0x2aab742500d0>,
#  ('PLZF_RARAg', 'down', 0.001): <maboss.result.Result at 0x2aab74253010>,
#  ('PLZF_RARAg', 'down', 0.01): <maboss.result.Result at 0x2aab74250c90>,
#  ('PLZF_RARAg', 'down', 0.1): <maboss.result.Result at 0x2aab74253290>,
#  ('PLZF_RARAg', 'down', 1): <maboss.result.Result at 0x2aab74252490>,
#  ('PLZF_RARAg', 'down', 10): <maboss.result.Result at 0x2aab74251290>,
#  ('PLZF_RARAg', 'down', 100): <maboss.result.Result at 0x2aab74253cd0>,
#  ('PLZF_RARAg', 'down', 1000): <maboss.result.Result at 0x2aab74251250>,
#  ('RARA', 'down', 0.001): <maboss.result.Result at 0x2aab74253b10>,
#  ('RARA', 'down', 0.01): <maboss.result.Result at 0x2aab742536d0>,
#  ('RARA', 'down', 0.1): <maboss.result.Result at 0x2aab74252690>,
#  ('RARA', 'down', 1): <maboss.result.Result at 0x2aab74253a10>,
#  ('RARA', 'down', 10): <maboss.result.Result at 0x2aab74252390>,
#  ('RARA', 'down', 100): <maboss.result.Result at 0x2aab74251c90>,
#  ('RARA', 'down', 1000): <maboss.result.Result at 0x2aab74252650>,
#  ('PML', 'down', 0.001): <maboss.result.Result at 0x2aab74253790>,
#  ('PML', 'down', 0.01): <maboss.result.Result at 0x2aab74251050>,
#  ('PML', 'down', 0.1): <maboss.result.Result at 0x2aab74252210>,
#  ('PML', 'down', 1): <maboss.result.Result at 0x2aab74251b50>,
#  ('PML', 'down', 10): <maboss.result.Result at 0x2aab74253e90>,
#  ('PML', 'down', 100): <maboss.result.Result at 0x2aab74251810>,
#  ('PML', 'down', 1000): <maboss.result.Result at 0x2aab74253150>,
#  ('PML_RARA', 'down', 0.001): <maboss.result.Result at 0x2aab74253910>,
#  ('PML_RARA', 'down', 0.01): <maboss.result.Result at 0x2aab74252590>,
#  ('PML_RARA', 'down', 0.1): <maboss.result.Result at 0x2aab74253690>,
#  ('PML_RARA', 'down', 1): <maboss.result.Result at 0x2aab74250bd0>,
#  ('PML_RARA', 'down', 10): <maboss.result.Result at 0x2aab74250750>,
#  ('PML_RARA', 'down', 100): <maboss.result.Result at 0x2aab74252750>,
#  ('PML_RARA', 'down', 1000): <maboss.result.Result at 0x2aab74252410>,
#  ('PLZF', 'down', 0.001): <maboss.result.Result at 0x2aab74251490>,
#  ('PLZF', 'down', 0.01): <maboss.result.Result at 0x2aab742517d0>,
#  ('PLZF', 'down', 0.1): <maboss.result.Result at 0x2aab74250150>,
#  ('PLZF', 'down', 1): <maboss.result.Result at 0x2aab74253550>,
#  ('PLZF', 'down', 10): <maboss.result.Result at 0x2aab74252810>,
#  ('PLZF', 'down', 100): <maboss.result.Result at 0x2aab74253d50>,
#  ('PLZF', 'down', 1000): <maboss.result.Result at 0x2aab74250810>,
#  ('PLZF_RARA', 'down', 0.001): <maboss.result.Result at 0x2aab74252610>,
#  ('PLZF_RARA', 'down', 0.01): <maboss.result.Result at 0x2aab74252990>,
#  ('PLZF_RARA', 'down', 0.1): <maboss.result.Result at 0x2aab74251890>,
#  ('PLZF_RARA', 'down', 1): <maboss.result.Result at 0x2aab74252b10>,
#  ('PLZF_RARA', 'down', 10): <maboss.result.Result at 0x2aab74250d90>,
#  ('PLZF_RARA', 'down', 100): <maboss.result.Result at 0x2aab74250790>,
#  ('PLZF_RARA', 'down', 1000): <maboss.result.Result at 0x2aab74252850>,
#  ('USP37', 'down', 0.001): <maboss.result.Result at 0x2aab74252a10>,
#  ('USP37', 'down', 0.01): <maboss.result.Result at 0x2aab742e6b50>,
#  ('USP37', 'down', 0.1): <maboss.result.Result at 0x2aab74253ad0>,
#  ('USP37', 'down', 1): <maboss.result.Result at 0x2aab74251010>,
#  ('USP37', 'down', 10): <maboss.result.Result at 0x2aab74252c50>,
#  ('USP37', 'down', 100): <maboss.result.Result at 0x2aab74252950>,
#  ('USP37', 'down', 1000): <maboss.result.Result at 0x2aab74251550>,
#  ('CoAct_COMP', 'down', 0.001): <maboss.result.Result at 0x2aab742525d0>,
#  ('CoAct_COMP', 'down', 0.01): <maboss.result.Result at 0x2aab743154d0>,
#  ('CoAct_COMP', 'down', 0.1): <maboss.result.Result at 0x2aab74252b50>,
#  ('CoAct_COMP', 'down', 1): <maboss.result.Result at 0x2aab74252cd0>,
#  ('CoAct_COMP', 'down', 10): <maboss.result.Result at 0x2aab742531d0>,
#  ('CoAct_COMP', 'down', 100): <maboss.result.Result at 0x2aab6be79350>,
#  ('CoAct_COMP', 'down', 1000): <maboss.result.Result at 0x2aab74250650>,
#  ('EZH2', 'down', 0.001): <maboss.result.Result at 0x2aab6be79850>,
#  ('EZH2', 'down', 0.01): <maboss.result.Result at 0x2aab6be7b150>,
#  ('EZH2', 'down', 0.1): <maboss.result.Result at 0x2aab6be7ac90>,
#  ('EZH2', 'down', 1): <maboss.result.Result at 0x2aab6be79d50>,
#  ('EZH2', 'down', 10): <maboss.result.Result at 0x2aab6be79b10>,
#  ('EZH2', 'down', 100): <maboss.result.Result at 0x2aab6be7bb50>,
#  ('EZH2', 'down', 1000): <maboss.result.Result at 0x2aab6be78bd0>,
#  ('PRC2', 'down', 0.001): <maboss.result.Result at 0x2aab6be78fd0>,
#  ('PRC2', 'down', 0.01): <maboss.result.Result at 0x2aab6be78210>,
#  ('PRC2', 'down', 0.1): <maboss.result.Result at 0x2aab6be7bbd0>,
#  ('PRC2', 'down', 1): <maboss.result.Result at 0x2aab6be7ab10>,
#  ('PRC2', 'down', 10): <maboss.result.Result at 0x2aab6be7aad0>,
#  ('PRC2', 'down', 100): <maboss.result.Result at 0x2aab6be78950>,
#  ('PRC2', 'down', 1000): <maboss.result.Result at 0x2aab6be798d0>,
#  ('CoRep_COMP', 'down', 0.001): <maboss.result.Result at 0x2aab6be7bcd0>,
#  ('CoRep_COMP', 'down', 0.01): <maboss.result.Result at 0x2aab6be792d0>,
#  ('CoRep_COMP', 'down', 0.1): <maboss.result.Result at 0x2aab6be7a390>,
#  ('CoRep_COMP', 'down', 1): <maboss.result.Result at 0x2aab6be7a990>,
#  ('CoRep_COMP', 'down', 10): <maboss.result.Result at 0x2aab6be7b290>,
#  ('CoRep_COMP', 'down', 100): <maboss.result.Result at 0x2aab6be78dd0>,
#  ('CoRep_COMP', 'down', 1000): <maboss.result.Result at 0x2aab6be78b90>,
#  ('CDKN1A', 'down', 0.001): <maboss.result.Result at 0x2aab6be785d0>,
#  ('CDKN1A', 'down', 0.01): <maboss.result.Result at 0x2aab6be79010>,
#  ('CDKN1A', 'down', 0.1): <maboss.result.Result at 0x2aab6be78450>,
#  ('CDKN1A', 'down', 1): <maboss.result.Result at 0x2aab6be7b9d0>,
#  ('CDKN1A', 'down', 10): <maboss.result.Result at 0x2aab6be7b650>,
#  ('CDKN1A', 'down', 100): <maboss.result.Result at 0x2aab6be795d0>,
#  ('CDKN1A', 'down', 1000): <maboss.result.Result at 0x2aab6be78510>,
#  ('CDKN1B', 'down', 0.001): <maboss.result.Result at 0x2aab6be79a50>,
#  ('CDKN1B', 'down', 0.01): <maboss.result.Result at 0x2aab6be78250>,
#  ('CDKN1B', 'down', 0.1): <maboss.result.Result at 0x2aab6be788d0>,
#  ('CDKN1B', 'down', 1): <maboss.result.Result at 0x2aab6be7bad0>,
#  ('CDKN1B', 'down', 10): <maboss.result.Result at 0x2aab6be78710>,
#  ('CDKN1B', 'down', 100): <maboss.result.Result at 0x2aab6be79790>,
#  ('CDKN1B', 'down', 1000): <maboss.result.Result at 0x2aab6be78110>,
#  ('CDKN2D', 'down', 0.001): <maboss.result.Result at 0x2aab6be7bfd0>,
#  ('CDKN2D', 'down', 0.01): <maboss.result.Result at 0x2aab6be78e90>,
#  ('CDKN2D', 'down', 0.1): <maboss.result.Result at 0x2aab6be7b110>,
#  ('CDKN2D', 'down', 1): <maboss.result.Result at 0x2aab6be7b910>,
#  ('CDKN2D', 'down', 10): <maboss.result.Result at 0x2aab6be7af10>,
#  ('CDKN2D', 'down', 100): <maboss.result.Result at 0x2aab6be7b990>,
#  ('CDKN2D', 'down', 1000): <maboss.result.Result at 0x2aab6be789d0>,
#  ('RB1', 'down', 0.001): <maboss.result.Result at 0x2aab6be7bf10>,
#  ('RB1', 'down', 0.01): <maboss.result.Result at 0x2aab6be7be50>,
#  ('RB1', 'down', 0.1): <maboss.result.Result at 0x2aab6be780d0>,
#  ('RB1', 'down', 1): <maboss.result.Result at 0x2aab6be79210>,
#  ('RB1', 'down', 10): <maboss.result.Result at 0x2aab6be79910>,
#  ('RB1', 'down', 100): <maboss.result.Result at 0x2aab6be79690>,
#  ('RB1', 'down', 1000): <maboss.result.Result at 0x2aab6be7a210>,
#  ('TP53', 'down', 0.001): <maboss.result.Result at 0x2aab6be78810>,
#  ('TP53', 'down', 0.01): <maboss.result.Result at 0x2aab6be7a310>,
#  ('TP53', 'down', 0.1): <maboss.result.Result at 0x2aab6be7af90>,
#  ('TP53', 'down', 1): <maboss.result.Result at 0x2aab6be7a350>,
#  ('TP53', 'down', 10): <maboss.result.Result at 0x2aab6be79d90>,
#  ('TP53', 'down', 100): <maboss.result.Result at 0x2aab6be7a0d0>,
#  ('TP53', 'down', 1000): <maboss.result.Result at 0x2aab6be7a3d0>,
#  ('SKP2', 'down', 0.001): <maboss.result.Result at 0x2aab6be79950>,
#  ('SKP2', 'down', 0.01): <maboss.result.Result at 0x2aab6be7bd10>,
#  ('SKP2', 'down', 0.1): <maboss.result.Result at 0x2aab6be7a590>,
#  ('SKP2', 'down', 1): <maboss.result.Result at 0x2aab6be78d10>,
#  ('SKP2', 'down', 10): <maboss.result.Result at 0x2aab6be79450>,
#  ('SKP2', 'down', 100): <maboss.result.Result at 0x2aab6be79a90>,
#  ('SKP2', 'down', 1000): <maboss.result.Result at 0x2aab6be7b410>,
#  ('MDM2', 'down', 0.001): <maboss.result.Result at 0x2aab6be7a7d0>,
#  ('MDM2', 'down', 0.01): <maboss.result.Result at 0x2aab6be78a50>,
#  ('MDM2', 'down', 0.1): <maboss.result.Result at 0x2aab6be7b950>,
#  ('MDM2', 'down', 1): <maboss.result.Result at 0x2aab6be79250>,
#  ('MDM2', 'down', 10): <maboss.result.Result at 0x2aab6be79f10>,
#  ('MDM2', 'down', 100): <maboss.result.Result at 0x2aab6be7a090>,
#  ('MDM2', 'down', 1000): <maboss.result.Result at 0x2aab6be7a810>,
#  ('CAK', 'down', 0.001): <maboss.result.Result at 0x2aab6be7ba50>,
#  ('CAK', 'down', 0.01): <maboss.result.Result at 0x2aab6be78b50>,
#  ('CAK', 'down', 0.1): <maboss.result.Result at 0x2aab6be79750>,
#  ('CAK', 'down', 1): <maboss.result.Result at 0x2aab74244150>,
#  ('CAK', 'down', 10): <maboss.result.Result at 0x2aab6be7bf90>,
#  ('CAK', 'down', 100): <maboss.result.Result at 0x2aab74244250>,
#  ('CAK', 'down', 1000): <maboss.result.Result at 0x2aab6be7a190>,
#  ('CCNA2', 'down', 0.001): <maboss.result.Result at 0x2aab74247f10>,
#  ('CCNA2', 'down', 0.01): <maboss.result.Result at 0x2aab74244ad0>,
#  ('CCNA2', 'down', 0.1): <maboss.result.Result at 0x2aab74246fd0>,
#  ('CCNA2', 'down', 1): <maboss.result.Result at 0x2aab74247310>,
#  ('CCNA2', 'down', 10): <maboss.result.Result at 0x2aab74247250>,
#  ('CCNA2', 'down', 100): <maboss.result.Result at 0x2aab74245750>,
#  ('CCNA2', 'down', 1000): <maboss.result.Result at 0x2aab74245650>,
#  ('CCND1', 'down', 0.001): <maboss.result.Result at 0x2aab742469d0>,
#  ('CCND1', 'down', 0.01): <maboss.result.Result at 0x2aab6c16ec50>,
#  ('CCND1', 'down', 0.1): <maboss.result.Result at 0x2aab742446d0>,
#  ('CCND1', 'down', 1): <maboss.result.Result at 0x2aab74244f10>,
#  ('CCND1', 'down', 10): <maboss.result.Result at 0x2aab74247210>,
#  ('CCND1', 'down', 100): <maboss.result.Result at 0x2aab74244950>,
#  ('CCND1', 'down', 1000): <maboss.result.Result at 0x2aab74244110>,
#  ('CCNE2', 'down', 0.001): <maboss.result.Result at 0x2aab74246c90>,
#  ('CCNE2', 'down', 0.01): <maboss.result.Result at 0x2aab74245150>,
#  ('CCNE2', 'down', 0.1): <maboss.result.Result at 0x2aab6be53250>,
#  ('CCNE2', 'down', 1): <maboss.result.Result at 0x2aab74244310>,
#  ('CCNE2', 'down', 10): <maboss.result.Result at 0x2aab74247610>,
#  ('CCNE2', 'down', 100): <maboss.result.Result at 0x2aab74246090>,
#  ('CCNE2', 'down', 1000): <maboss.result.Result at 0x2aab74245f90>,
#  ('CDK4_6', 'down', 0.001): <maboss.result.Result at 0x2aab74247c10>,
#  ('CDK4_6', 'down', 0.01): <maboss.result.Result at 0x2aab74244650>,
#  ('CDK4_6', 'down', 0.1): <maboss.result.Result at 0x2aab6c16eed0>,
#  ('CDK4_6', 'down', 1): <maboss.result.Result at 0x2aab74244a90>,
#  ('CDK4_6', 'down', 10): <maboss.result.Result at 0x2aab74244410>,
#  ('CDK4_6', 'down', 100): <maboss.result.Result at 0x2aab74247e90>,
#  ('CDK4_6', 'down', 1000): <maboss.result.Result at 0x2aab74246110>,
#  ('CDK2', 'down', 0.001): <maboss.result.Result at 0x2aab74246a50>,
#  ('CDK2', 'down', 0.01): <maboss.result.Result at 0x2aab742476d0>,
#  ('CDK2', 'down', 0.1): <maboss.result.Result at 0x2aab74245ed0>,
#  ('CDK2', 'down', 1): <maboss.result.Result at 0x2aab742450d0>,
#  ('CDK2', 'down', 10): <maboss.result.Result at 0x2aab742444d0>,
#  ('CDK2', 'down', 100): <maboss.result.Result at 0x2aab74246010>,
#  ('CDK2', 'down', 1000): <maboss.result.Result at 0x2aab746b7a50>,
#  ('E2F1', 'down', 0.001): <maboss.result.Result at 0x2aab74245f50>,
#  ('E2F1', 'down', 0.01): <maboss.result.Result at 0x2aab74245b50>,
#  ('E2F1', 'down', 0.1): <maboss.result.Result at 0x2aab74247090>,
#  ('E2F1', 'down', 1): <maboss.result.Result at 0x2aab74244f50>,
#  ('E2F1', 'down', 10): <maboss.result.Result at 0x2aab74246690>,
#  ('E2F1', 'down', 100): <maboss.result.Result at 0x2aab74246390>,
#  ('E2F1', 'down', 1000): <maboss.result.Result at 0x2aab74244050>,
#  ('MYC', 'down', 0.001): <maboss.result.Result at 0x2aab742441d0>,
#  ('MYC', 'down', 0.01): <maboss.result.Result at 0x2aab74245790>,
#  ('MYC', 'down', 0.1): <maboss.result.Result at 0x2aab74245a50>,
#  ('MYC', 'down', 1): <maboss.result.Result at 0x2aab74245010>,
#  ('MYC', 'down', 10): <maboss.result.Result at 0x2aab74246750>,
#  ('MYC', 'down', 100): <maboss.result.Result at 0x2aab74245390>,
#  ('MYC', 'down', 1000): <maboss.result.Result at 0x2aab74247e50>,
#  ('DUSP6', 'down', 0.001): <maboss.result.Result at 0x2aab74244990>,
#  ('DUSP6', 'down', 0.01): <maboss.result.Result at 0x2aab74245550>,
#  ('DUSP6', 'down', 0.1): <maboss.result.Result at 0x2aab74247510>,
#  ('DUSP6', 'down', 1): <maboss.result.Result at 0x2aab74244dd0>,
#  ('DUSP6', 'down', 10): <maboss.result.Result at 0x2aab74246790>,
#  ('DUSP6', 'down', 100): <maboss.result.Result at 0x2aab74245450>,
#  ('DUSP6', 'down', 1000): <maboss.result.Result at 0x2aab74244190>,
#  ('POU2F1', 'down', 0.001): <maboss.result.Result at 0x2aab74245d90>,
#  ('POU2F1', 'down', 0.01): <maboss.result.Result at 0x2aab742460d0>,
#  ('POU2F1', 'down', 0.1): <maboss.result.Result at 0x2aab74244b50>,
#  ('POU2F1', 'down', 1): <maboss.result.Result at 0x2aab742442d0>,
#  ('POU2F1', 'down', 10): <maboss.result.Result at 0x2aab742459d0>,
#  ('POU2F1', 'down', 100): <maboss.result.Result at 0x2aab74246490>,
#  ('POU2F1', 'down', 1000): <maboss.result.Result at 0x2aab74246a90>,
#  ('GATA2', 'down', 0.001): <maboss.result.Result at 0x2aab742475d0>,
#  ('GATA2', 'down', 0.01): <maboss.result.Result at 0x2aab74244510>,
#  ('GATA2', 'down', 0.1): <maboss.result.Result at 0x2aab74245b90>,
#  ('GATA2', 'down', 1): <maboss.result.Result at 0x2aab74244610>,
#  ('GATA2', 'down', 10): <maboss.result.Result at 0x2aab742465d0>,
#  ('GATA2', 'down', 100): <maboss.result.Result at 0x2aab74246350>,
#  ('GATA2', 'down', 1000): <maboss.result.Result at 0x2aab742443d0>,
#  ('RUNX1', 'down', 0.001): <maboss.result.Result at 0x2aab74244a50>,
#  ('RUNX1', 'down', 0.01): <maboss.result.Result at 0x2aab74247190>,
#  ('RUNX1', 'down', 0.1): <maboss.result.Result at 0x2aab74244c10>,
#  ('RUNX1', 'down', 1): <maboss.result.Result at 0x2aab74244f90>,
#  ('RUNX1', 'down', 10): <maboss.result.Result at 0x2aab74247410>,
#  ('RUNX1', 'down', 100): <maboss.result.Result at 0x2aab74244bd0>,
#  ('RUNX1', 'down', 1000): <maboss.result.Result at 0x2aab74246590>,
#  ('SPI1', 'down', 0.001): <maboss.result.Result at 0x2aab74245510>,
#  ('SPI1', 'down', 0.01): <maboss.result.Result at 0x2aab74244550>,
#  ('SPI1', 'down', 0.1): <maboss.result.Result at 0x2aab74244450>,
#  ('SPI1', 'down', 1): <maboss.result.Result at 0x2aab742473d0>,
#  ('SPI1', 'down', 10): <maboss.result.Result at 0x2aab74246510>,
#  ('SPI1', 'down', 100): <maboss.result.Result at 0x2aab742445d0>,
#  ('SPI1', 'down', 1000): <maboss.result.Result at 0x2aab6c00ce50>,
#  ('CEBPAB', 'down', 0.001): <maboss.result.Result at 0x2aab6c16cb50>,
#  ('CEBPAB', 'down', 0.01): <maboss.result.Result at 0x2aab6c00cdd0>,
#  ('CEBPAB', 'down', 0.1): <maboss.result.Result at 0x2aab6c00fa90>,
#  ('CEBPAB', 'down', 1): <maboss.result.Result at 0x2aab6c00cf90>,
#  ('CEBPAB', 'down', 10): <maboss.result.Result at 0x2aab74247d50>,
#  ('CEBPAB', 'down', 100): <maboss.result.Result at 0x2aab6c00f810>,
#  ('CEBPAB', 'down', 1000): <maboss.result.Result at 0x2aab744ca010>,
#  ('CEBPE', 'down', 0.001): <maboss.result.Result at 0x2aab6c00cfd0>,
#  ('CEBPE', 'down', 0.01): <maboss.result.Result at 0x2aab74245210>,
#  ('CEBPE', 'down', 0.1): <maboss.result.Result at 0x2aab6c00f4d0>,
#  ('CEBPE', 'down', 1): <maboss.result.Result at 0x2aab7424c150>,
#  ('CEBPE', 'down', 10): <maboss.result.Result at 0x2aab6c00e210>,
#  ('CEBPE', 'down', 100): <maboss.result.Result at 0x2aab7424d390>,
#  ('CEBPE', 'down', 1000): <maboss.result.Result at 0x2aab742f36d0>,
#  ('RARB', 'down', 0.001): <maboss.result.Result at 0x2aab7424f9d0>,
#  ('RARB', 'down', 0.01): <maboss.result.Result at 0x2aab6c00d6d0>,
#  ('RARB', 'down', 0.1): <maboss.result.Result at 0x2aab7424ecd0>,
#  ('RARB', 'down', 1): <maboss.result.Result at 0x2aab6c00ddd0>,
#  ('RARB', 'down', 10): <maboss.result.Result at 0x2aab7424c1d0>,
#  ('RARB', 'down', 100): <maboss.result.Result at 0x2aab6c00fd90>,
#  ('RARB', 'down', 1000): <maboss.result.Result at 0x2aab7424e3d0>}

# %%
# Transformation of the data structure of the results to build the plots.

import pandas as pd
import numpy as np

# Initialize an empty dictionary to store nested results
nested_res = {}

# Iterate over all_results dictionary and structure the data into nested_res
for (key1, key2, key3), value in all_results.items():
    if key1 not in nested_res:
        nested_res[key1] = {}
    nested_res[key1][(key2, key3)] = value.get_last_nodes_probtraj().iloc[0]['E2F1']

# Convert nested_res dictionary to a DataFrame
PSA_plot_df = pd.DataFrame.from_dict(nested_res, orient='index')

# Transpose the DataFrame to have the desired format
PSA_plot_df = PSA_plot_df.T

# Define the columns to filter. These are the selected nodes for the analysis.
filtered_columns = ['PML', 'PML_RARA', 'PLZF', 'PLZF_RARA', 'USP37', 'CoAct_COMP', 'EZH2', 
                    'PRC2', 'CoRep_COMP', 'CDKN1A', 'CDKN1B', 'CDKN2D', 'RB1', 'TP53', 'SKP2', 
                    'MDM2', 'CAK', 'CCNA2', 'CCND1', 'CCNE2', 'CDK4_6', 'CDK2', 'E2F1', 
                    'MYC', 'POU2F1', 'GATA2', 'SPI1', 'CEBPAB']

# Filter the DataFrame to include only the specified columns
PSA_plot_df_filtered = PSA_plot_df[filtered_columns]

# Display the filtered DataFrame
PSA_plot_df_filtered
# Out:
#                   PML  PML_RARA    PLZF  PLZF_RARA   USP37  CoAct_COMP  \
# up   0.001     0.1233    0.1220  0.1261     0.0001  0.1000      0.1272
#      0.010     0.1297    0.1222  0.1298     0.0020  0.1003      0.1265
#      0.100     0.1236    0.1299  0.1223     0.0196  0.1072      0.1281
#      1.000     0.1264    0.1305  0.1216     0.1213  0.1207      0.1227
#      10.000    0.1245    0.1236  0.1302     0.2627  0.1368      0.1182
#      100.000   0.1266    0.1214  0.1265     0.2878  0.1510      0.1250
#      1000.000  0.1245    0.1225  0.1281     0.2887  0.1502      0.1236
# down 0.001     0.1096    0.1300  0.1251     0.1688  0.1858      0.1244
#      0.010     0.1192    0.1299  0.1200     0.1709  0.1887      0.1274
#      0.100     0.1131    0.1257  0.1239     0.1609  0.1804      0.1283
#      1.000     0.1259    0.1217  0.1306     0.1213  0.1257      0.1270
#      10.000    0.1375    0.1212  0.1291     0.1131  0.0530      0.1223
#      100.000   0.1403    0.1228  0.1289     0.1040  0.0361      0.1271
#      1000.000  0.1425    0.1242  0.1257     0.1105  0.0343      0.1264
#
#                  EZH2    PRC2  CoRep_COMP  CDKN1A  CDKN1B  CDKN2D     RB1  \
# up   0.001     0.1266  0.1265      0.1268  0.1681  0.1261  0.1197  0.1278
#      0.010     0.1202  0.1278      0.1239  0.1604  0.1243  0.1289  0.1249
#      0.100     0.1252  0.1265      0.1204  0.1571  0.1252  0.1241  0.1239
#      1.000     0.1262  0.1263      0.1282  0.1221  0.1233  0.1277  0.1279
#      10.000    0.1268  0.1213      0.1305  0.0816  0.1231  0.1274  0.1221
#      100.000   0.1276  0.1238      0.1252  0.0744  0.1241  0.1230  0.1217
#      1000.000  0.1239  0.1221      0.1292  0.0764  0.1206  0.1256  0.1298
# down 0.001     0.1262  0.1289      0.1229  0.0992  0.1226  0.1243  0.0003
#      0.010     0.1289  0.1274      0.1267  0.0953  0.1296  0.1242  0.0029
#      0.100     0.1258  0.1280      0.1234  0.0998  0.1201  0.1261  0.0204
#      1.000     0.1291  0.1316      0.1273  0.1258  0.1277  0.1285  0.1286
#      10.000    0.1229  0.1271      0.1266  0.1391  0.1290  0.1289  0.2323
#      100.000   0.1218  0.1315      0.1302  0.1469  0.1283  0.1192  0.2522
#      1000.000  0.1194  0.1252      0.1195  0.1374  0.1261  0.1186  0.2523
#
#                  TP53    SKP2    MDM2     CAK   CCNA2   CCND1   CCNE2  CDK4_6  \
# up   0.001     0.1320  0.1295  0.1169  0.1198  0.1243  0.1246  0.1325  0.1287
#      0.010     0.1201  0.1253  0.1271  0.1159  0.1201  0.1244  0.1232  0.1239
#      0.100     0.1207  0.1237  0.1218  0.1200  0.1270  0.1240  0.1204  0.1264
#      1.000     0.1204  0.1219  0.1249  0.1253  0.1237  0.1253  0.1249  0.1267
#      10.000    0.1244  0.1214  0.1250  0.1343  0.1247  0.1240  0.1311  0.1203
#      100.000   0.1244  0.1240  0.1253  0.1286  0.1283  0.1247  0.1203  0.1213
#      1000.000  0.1297  0.1258  0.1198  0.1283  0.1273  0.1282  0.1270  0.1263
# down 0.001     0.1262  0.1223  0.1217  0.1519  0.1246  0.1271  0.1269  0.1234
#      0.010     0.1225  0.1304  0.1239  0.1648  0.1198  0.1241  0.1251  0.1225
#      0.100     0.1262  0.1271  0.1292  0.1465  0.1214  0.1310  0.1219  0.1287
#      1.000     0.1282  0.1223  0.1316  0.1264  0.1220  0.1260  0.1280  0.1246
#      10.000    0.1256  0.1197  0.1187  0.1096  0.1169  0.1226  0.1265  0.1297
#      100.000   0.1225  0.1267  0.1222  0.1076  0.1246  0.1259  0.1221  0.1295
#      1000.000  0.1333  0.1217  0.1172  0.1061  0.1319  0.1209  0.1283  0.1232
#
#                  CDK2      E2F1     MYC  POU2F1   GATA2    SPI1  CEBPAB
# up   0.001     0.1263  0.105300  0.0960  0.1240  0.1199  0.1205  0.1326
#      0.010     0.1197  0.104000  0.1003  0.1279  0.1243  0.1262  0.1240
#      0.100     0.1236  0.110200  0.1048  0.1265  0.1252  0.1214  0.1334
#      1.000     0.1274  0.126600  0.1175  0.1272  0.1244  0.1259  0.1271
#      10.000    0.1261  0.143300  0.1601  0.1215  0.1210  0.1235  0.1229
#      100.000   0.1275  0.143000  0.1642  0.1220  0.1332  0.1259  0.1201
#      1000.000  0.1218  0.150500  0.1634  0.1221  0.1269  0.1206  0.1189
# down 0.001     0.1266  0.979607  0.4981  0.1231  0.1173  0.1233  0.0005
#      0.010     0.1256  0.816916  0.4899  0.1273  0.1238  0.1242  0.0022
#      0.100     0.1271  0.288669  0.4135  0.1256  0.1205  0.1296  0.0235
#      1.000     0.1210  0.127100  0.1254  0.1293  0.1212  0.1258  0.1206
#      10.000    0.1224  0.061700  0.0210  0.1346  0.1271  0.1307  0.1940
#      100.000   0.1232  0.058200  0.0199  0.1223  0.1205  0.1238  0.1997
#      1000.000  0.1188  0.056100  0.0194  0.1227  0.1255  0.1222  0.2055

# %%
# Plot the impact of all parameter changes in a pair of polar plots.

from matplotlib.ticker import FixedLocator, FixedFormatter

cat = list(PSA_plot_df_filtered.columns)
cat = [*cat, cat[0]] #to close the radar, duplicate the first column
n_points = len(cat)

#As we have n categories the radar chart shoud have n radial axis
#angles need to be converted to radian so we multiply by 2*pi and create the list of angles:
label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(cat))


fig, (ax1, ax2) = plt.subplots(1, 2, subplot_kw=dict(projection='polar'), facecolor="white", figsize=(30, 30))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.4, hspace=None)

for index, row in PSA_plot_df_filtered.iterrows():
    if 'up' in index:
        ax1.fill(label_loc, [*row.tolist(), row.tolist()[0]], alpha=0.4, color='#84F24C')
        ax1.fill_between(label_loc, [*row.tolist(), row.tolist()[0]], PSA_plot_df_filtered.max().max()*1.05, alpha=0.2, color='#FFF055')
        
        if index[1]==1:
            ax1.plot(label_loc, [*row.tolist(), row.tolist()[0]], '-', color='white', label=index[1], linewidth=4)
        elif index[1]>1:
            ax1.plot(label_loc, [*row.tolist(), row.tolist()[0]], '--', color='blue', label='{:.0f}'.format(index[1]), linewidth=0.91*(index[1]**0.086))
        elif index[1]<1:
            ax1.plot(label_loc, [*row.tolist(), row.tolist()[0]], '--', color='red', label=index[1], linewidth=1.54*(index[1]**0.266))

    if 'down' in index:
        ax2.fill(label_loc, [*row.tolist(), row.tolist()[0]], alpha=0.4, color='#84F24C')
        ax2.fill_between(label_loc, [*row.tolist(), row.tolist()[0]], PSA_plot_df_filtered.max().max()*1.05, alpha=0.2, color='#FFF055')
        
        if index[1]==1:
            ax2.plot(label_loc, [*row.tolist(), row.tolist()[0]], '-', color='white', label=index[1], linewidth=4)
        elif index[1]>1:
            ax2.plot(label_loc, [*row.tolist(), row.tolist()[0]], '--', color='blue', label='{:.0f}'.format(index[1]), linewidth=0.91*(index[1]**0.086))
        elif index[1]<1:
            ax2.plot(label_loc, [*row.tolist(), row.tolist()[0]], '--', color='red', label=index[1], linewidth=1.54*(index[1]**0.266))

#Set titles.
ax1.set_title('Variation of activation rates', y=1.2, fontsize=30)
ax2.set_title('Variation of deactivation rates', y=1.2, fontsize=30)

#Setting of collective visual properties.
for ax in [ax1, ax2]:

    # Fix axis to go in the right order and start at 12 o'clock.
    ax.set_theta_offset(np.pi / 2)
    ax.set_theta_direction(-1)
    #Draw axis lines for each angle and label.
    ax.set_thetagrids(np.degrees(label_loc), cat)

    # Go through labels and adjust alignment based on where it is in the circle.
    #for ax in [ax1, ax2]:
    for label, angle in zip(ax.get_xticklabels(), label_loc):
        # if angle in (0, np.pi):
        #label.set_horizontalalignment('center')
        if 0 < angle < np.pi:
            label.set_horizontalalignment('left')
        else:
            label.set_horizontalalignment('right')
   
    #Set symlog scale
    ax.set_yscale('symlog', linthresh=0.2)
    
    range_yvalues = np.arange(0, PSA_plot_df_filtered.max().max()*1.05, 0.1)
    ax.set_rgrids(range_yvalues)
    ax.yaxis.set_major_locator(FixedLocator(range_yvalues))
    ax.yaxis.set_major_formatter(FixedFormatter([f'{val:.1f}' for val in range_yvalues]))
    
    # Set position of y-labels (0-100) to be in the middle of the first two axes.
    ax.set_rlabel_position(180 / n_points)
    #Make the y-axis (0-100) labels smaller.
    ax.tick_params(axis='y', labelsize=15)    
    # Change the color of the circular gridlines.
    ax.grid(color='#AAAAAA', linewidth=0.2)
    #Change the color of the outermost gridline (the spine).
    ax.spines['polar'].set_color('#eaeaea')
    
    # Add legend.
    ax.legend(loc='upper right', bbox_to_anchor=(1.25, 1.2), fontsize=20, title='Factor', title_fontsize=20, facecolor='#F5F5F5')
    #Make the y-axis (0-100) labels smaller.
    ax.tick_params(labelsize=18)

# %% [markdown]
# The resulting polar plots display the impact of the variations of the activation (left) and deactivation (right) rates for the model nodes, excepting input and output nodes, onto the probability to reach the proliferative (green area) versus differentiated (yellow area) attractor.
# The initial state representing GMP cells was selected to perform stochastic simulations under variations of the activation or inactivation transition rates for each node, each time multiplying one of them by one of the following factors: 0.001, 0.01, 0.1, 1, 10, 100, 1,000
# The probability (between 0 and 1) of the proliferative attractor for each condition is plotted as a vertex of a polygon (one for each rate variant).
# The polygon corresponding to the default transition rates (set to 1) is displayed in white.
# The blue polygons correspond to transition rates higher than the default, whereas the red polygons correspond to transition rates lower than the default.
# For example, decreasing the activation rate or increasing the deactivation rate of the node MYC reduces the probability to reach the proliferative attractor.
# These simulation thereby point to potential targets for combinatorial therapies to treat APL.

# %%
# Plot the impacts of parameter changes for each node in individual bar plots.

# Define the lists for "up" and "down" differences, which will be used to represent the differentiation in the barplot
diff_up_list = [1] * 7  # Represents full height bars for the "up" condition
diff_down_list = [-1] * 7  # Represents full height bars for the "down" condition

# Iterate over each column in the DataFrame `PSA_plot_df_filtered`
for col_name in PSA_plot_df_filtered.columns:
    temp_dict = {}  # Initialize a temporary dictionary to store rates and values for 'up' and 'down'
    
    # Extract the Series (column data) for the current column
    series = PSA_plot_df_filtered[col_name]
    
    # Create the list of rates, which are the second element of the index (assumed to be tuples)
    temp_dict['rates'] = [PSA_plot_df_filtered.index[i][1] for i in range(int(len(PSA_plot_df_filtered)/2))]
    
    # Extract and store the 'up' and 'down' values for the corresponding rates
    temp_dict['up'] = series.loc['up'].reindex(temp_dict['rates']).tolist()
    temp_dict['down'] = series.loc['down'].reindex(temp_dict['rates']).tolist()
    
    # Create a DataFrame from the temporary dictionary
    df = pd.DataFrame(temp_dict)
    
    # Multiply the 'down' values by -1 to invert them (for plotting on the negative side of the y-axis)
    df['down'] = df['down'] * -1
    
    # Convert 'rates' to string for consistent labeling
    df['rates'] = df['rates'].astype(str)
    
    # Set 'rates' as the index of the DataFrame
    df.set_index('rates', inplace=True)
  
    # Generate a range object for bar positions
    rates = range(len(df))
    
    # Create a plot figure and axis
    fig, axes = plt.subplots(figsize=(10,5))
    
    # Plot background bars for the "up" and "down" conditions using `diff_up_list` and `diff_down_list`
    axes.bar(rates, diff_up_list, align='center', color='#FFF055', zorder=0, width=0.9)
    axes.bar(rates, diff_down_list, align='center', color='#FFF055', zorder=0, width=0.9)
    
    # Overlay the actual "up" and "down" data on top of the background bars
    axes.bar(rates, df['up'], align='center', color='#84F24C', zorder=1, width=0.9)
    axes.bar(rates, df['down'], align='center', color='#84F24C', zorder=1, width=0.9)
    
    # Set the title for the plot, based on the column name
    axes.set_title(col_name, fontsize=18, pad=15, color='black')
    
    # Draw a white horizontal line at y=0 to separate the up and down bars
    axes.axhline(y=0, color='white', linestyle='-', linewidth=4, zorder=3)
    
    # Draw dashed black lines at the up and down values for rate 1.0
    axes.axhline(y=df.loc['1.0']['up'], color='black', linestyle='--', linewidth=0.6, zorder=3)
    axes.axhline(y=df.loc['1.0']['down'], color='black', linestyle='--', linewidth=0.6, zorder=3)
    
    # Remove plot margins
    plt.margins(0, 0)
    
    # Set y-axis label
    axes.set_ylabel('Probability', fontsize=15)
    
    # Set x-axis label
    axes.set_xlabel('Factor', fontsize=15)

    # Customize x-axis tick labels with rates formatted as strings
    plt.xticks(rates, [(f"{float(v):.10g}") for v in df.index.tolist()], fontsize=15)
    
    # Define y-axis ticks and labels
    y_ticks= [1, 0.75, 0.5, 0.25, 0, -0.25, -0.5, -0.75, -1]
    axes.yaxis.set_major_locator(FixedLocator(y_ticks))  # Set fixed y-tick positions
    axes.yaxis.set_major_formatter(FixedFormatter([str(abs(tick)) for tick in y_ticks]))  # Format y-tick labels as absolute values
    plt.yticks(fontsize=12)
    
    # Add text labels to the right side of the plot for activation and deactivation rates
    axes.text(6.5, 0.1, 'Activation rates', rotation=90, fontsize=13)
    axes.text(6.5, -0.9, 'Deactivation rates', rotation=270, fontsize=13)
    
    # Hide all the plot spines (the box around the plot)
    for spine in axes.spines.values():
        spine.set_visible(False)
# Out:
# /tmp/ipykernel_450/803949938.py:37: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(figsize=(10,5))

# %% [markdown]
# These barplots display the impact of individual nodes. In each barplot, the upper side denote the variations in the activation rates, whereas the bottom side denotes the variations in the deactivation rates. In each bar, the green section represents the probability of the proliferative attractor, and the yellow section represents the probability of the differentiated attractor. The dashed lines denote the probabilities corresponding to the default transition rates (set to 1).
